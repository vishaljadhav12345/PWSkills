# %% [markdown]
# # **Theory Questions:**

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#
# - Function: A block of code defined using def or lambda that operates independently.
#
# - Method: A function that belongs to an object (like a list or string).
#
# - Example:

# %%
def greet():
    return "Hello"

text = "hello"
print(text.upper())

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.
#
# - Parameter: A variable listed in a function’s definition.
#
# - Argument: A value passed to a function when it's called.
#
# - Example:

# %%
def add(a, b):
    return a + b

result = add(3, 5)

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?
#
# - Ways to define:
#
#  - Using def
#
#  - Using lambda (anonymous)
#
# -  Ways to call:
#
#  - Directly by name with arguments
#
#  - Using keyword or default arguments
#
# - Example:

# %%
# def
def square(x):
    return x * x

# lambda
double = lambda x: x * 2

print(square(4))
print(double(5))

# %% [markdown]
# 4. What is the purpose of the return statement in a Python function?
#
# - The return statement sends a result back to the caller and exits the function.
#
# - Example:

# %%
def multiply(x, y):
    return x * y

print(multiply(2, 3))

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?
#
# - Iterable: Any object that can be looped over (e.g., list, tuple).
#
# - Iterator: Object with __next__() and __iter__() methods.
#
# - Example:

# %%
lst = [1, 2, 3]
it = iter(lst)
print(next(it))

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined.
#
# - Generators are special functions that yield values one at a time using yield keyword.
#
# - Example:

# %%
def count_up_to(n):
    for i in range(n):
        yield i

gen = count_up_to(3)
print(next(gen))

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
#
# - Memory-efficient: No need to store all values in memory
#
# - Lazy evaluation: Values are produced only when needed
#
# - Example:

# %%
def infinite_counter():
    n = 0
    while True:
        yield n
        n += 1

counter = infinite_counter()

for _ in range(10):
    print(next(counter))

# %% [markdown]
# 8. What is a lambda function in Python and when is it typically used?
#
# - A lambda is an anonymous, one-line function often used for short, throwaway  operations, especially in map(), filter(), and sort().
#
# - Example:

# %%
add = lambda x, y: x + y
print(add(3, 4))

# %% [markdown]
# 9. Explain the purpose and usage of the map() function in Python.
#
# - map() applies a function to each item in an iterable.
#
# - Example:

# %%
nums = [1, 2, 3]
squares = list(map(lambda x: x*x, nums))
print(squares)

# %% [markdown]
# 10. What is the difference between map(), reduce(), and filter()?
#
# - map()
#  - Use - Apply a function to all
#  - Example - map(lambda x: x*2, [1,2]) → [2,4]
# - filter()
#  - Use - Filter values by condition	filter
#  - Example - filter(lambda x: x>2, [1,3,4]) → [3,4]
# - reduce()
#  - Use - Reduce to a single value
#  - Example - reduce(lambda x,y: x+y, [1,2,3]) → 6

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using reduce function on this given list:[47,11,42,13]
#
# - Mechanism of reduce() for Summation
# The reduce function applies the sum operation cumulatively from left to right:
#
#  - Step 1 : Process first two elements
# 47 + 11 = 58
# Remaining list: 58,.
#  - Step 2 : Combine result with next element 58 + 42 = 100
#    Remaining list:
#
#  - Step 3 : Combine with final element
# 100 + 13 = 113
#
# - On Paper with example -
#
# ![Q 11.jpg](data:image/jpeg;base64,...)

# %%
from functools import reduce

nums = [47, 11, 42, 13]
result = reduce(lambda x, y: x + y, nums)
print(result)
# Out:
# 113

# %% [markdown]
# # **Practical Questions:**

# %% [markdown]
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

# %%
def sum_even_numbers(numbers):
    return sum(num for num in numbers if num % 2 == 0)

test_list = [1, 2, 3, 4, 5, 6]
print(sum_even_numbers(test_list))

# %% [markdown]
# 2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(s):
    return s[::-1]

print(reverse_string("hello"))

# %% [markdown]
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

# %%
def square_list(numbers):
    return [num ** 2 for num in numbers]

print(square_list([1, 2, 3, 4]))

# %% [markdown]
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(n):
    if n <= 1:
        return False
    if n <= 3:
        return True
    if n % 2 == 0 or n % 3 == 0:
        return False
    i = 5
    while i * i <= n:
        if n % i == 0 or n % (i + 2) == 0:
            return False
        i += 6
    return True
primes_1_to_200 = [num for num in range(1, 201) if is_prime(num)]
print(primes_1_to_200)

# %% [markdown]
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

# %%
class FibonacciIterator:
    def __init__(self, n_terms):
        self.n_terms = n_terms
        self.index = 0
        self.a, self.b = 0, 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.index >= self.n_terms:
            raise StopIteration
        if self.index == 0:
            self.index += 1
            return 0
        elif self.index == 1:
            self.index += 1
            return 1
        else:
            self.a, self.b = self.b, self.a + self.b
            self.index += 1
            return self.a

fib_iter = FibonacciIterator(10)
print(list(fib_iter))

# %% [markdown]
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(exponent):
    for i in range(exponent + 1):
        yield 2 ** i

print(list(powers_of_two(5)))

# %% [markdown]
# 7. Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_lines(filename):
    with open(filename, 'r') as f:
        for line in f:
            yield line.strip()
for line in read_lines("example.txt"):
    print(line)

# %% [markdown]
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
sample_tuples = [(1, 3), (4, 1), (5, 2), (2, 4)]
sorted_tuples = sorted(sample_tuples, key=lambda x: x[1])
print(sorted_tuples)

# %% [markdown]
# 9. Write a Python program that uses map() to convert a list of temperatures from Celsius to Fahrenheit.

# %%
def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32

celsius_temps = [0, 20, 37, 100]
fahrenheit_temps = list(map(celsius_to_fahrenheit, celsius_temps))
print(fahrenheit_temps)

# %% [markdown]
# 10. Create a Python program that uses filter() to remove all the vowels from a given string.

# %%
def remove_vowels(s):
    vowels = 'aeiouAEIOU'
    return ''.join(filter(lambda char: char not in vowels, s))

print(remove_vowels('Hello World'))

# %% [markdown]
# 11. Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
#
#  Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the product of the price per item and the quantity. The product should be increased by 10,- € if the value of the order is smaller than 100,00 €.
#  Write a Python program using lambda and map.
#
#  ![Screenshot 2025-06-12 211839.png](data:image/png;base64,...)

# %%
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

result = list(map(lambda order:
                  (order[0], round(order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0), 2)),
                  orders))

print(result)
