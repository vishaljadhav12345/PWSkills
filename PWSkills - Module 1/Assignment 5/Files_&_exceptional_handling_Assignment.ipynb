# %% [markdown]
# # **Files, exceptional handling, logging and memory management Questions**

# %% [markdown]
# **1. What is the difference between interpreted and compiled languages?**
#
# - Compiled languages :  are those where the source code you write is translated entirely into machine code before it is run. This translation is done by a compiler, and it results in an executable file (like .exe on Windows). When you run the program, you're executing this compiled file, which is already in a format the computer understands, so it tends to run very fast. However, if there's any error in the code, the compiler will catch it before the program is even run.
# In C, if you write a program called hello.c, you must compile it first using a compiler like gcc.
#
# - Interpreted languages, on the other hand, do not produce a separate executable file. Instead, an interpreter runs through the code line by line at runtime, translating it and executing it immediately. This makes interpreted languages easier for quick testing and scripting, but generally slower in performance compared to compiled languages.
# In Python, you simply run: python hello.py

# %% [markdown]
# **2. What is exception handling in Python?**
#
# - Exception handling in Python is a way to gracefully handle runtime errors in your program so that it doesn’t crash unexpectedly. It allows you to detect, catch, and respond to exceptions (errors) using try, except, else, and finally blocks.
#
# - Example :

# %%
try:
    number = int(input("Enter a number: "))
    result = 10 / number
    print("Result:", result)
except ZeroDivisionError:
    print("Error: You cannot divide by zero!")
except ValueError:
    print("Error: Invalid input! Please enter a number.")
# Out:
# Enter a number: 67
# Result: 0.14925373134328357

# %% [markdown]
# **3. What is the purpose of the finally block in exception handling?**
#
# - The finally block in Python is used to define a section of code that will always execute, no matter what happens in the try or except blocks.
# Its main purpose is to perform cleanup actions—like closing files, releasing resources, disconnecting from databases, etc.—regardless of whether an exception occurred or not.
#
# - Example :

# %%
try:
    file = open("sample.txt", "r")
    content = file.read()
    print(content)
except FileNotFoundError:
    print("File not found!")
finally:
    print("Closing file...")
# Out:
# File not found!
# Closing file...

# %% [markdown]
# **4. What is logging in Python?**
#
# - Logging is the process of recording events, errors, and informational messages during program execution.
# Python’s logging module provides a flexible framework for emitting log messages from Python programs.
#
# - Logging in Python is the process of tracking events that happen when software runs. Instead of using print() for debugging, Python’s logging module provides a flexible way to record messages, such as errors, warnings, or custom messages, to different outputs like the console, files, or even remote servers.
#
# - Logging helps in:
#
#  - Debugging
#
#  - Monitoring applications in production
#
#  - Keeping audit trails of application behavior
#
# - Example :

# %%
import logging

# Set up basic logging configuration
logging.basicConfig(level=logging.INFO)

# Logging messages
logging.debug("This is a debug message")     # Not shown because default level is INFO
logging.info("This is an info message")      # Shown
logging.warning("This is a warning message") # Shown
logging.error("This is an error message")    # Shown
logging.critical("This is a critical message") # Shown
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %% [markdown]
# **5. What is the significance of the __del__ method in Python?**
#
# - The __ del __ method is a destructor called when an object is about to be destroyed.
# It is used for cleanup actions, such as releasing external resources, but its use is generally discouraged due to unpredictability in garbage collection timing.
#
# - The __ del __  method in Python is a special method (also called a "destructor") that is automatically called when an object is about to be destroyed or garbage collected.
#
# - It is typically used for cleanup tasks like:
#
#  - Closing open files
#
#  - Releasing network or database connections
#
#  - Freeing up any acquired resources
#
# - Example :

# %%
class FileHandler:
    def __init__(self, filename):
        self.file = open(filename, 'w')
        print("File opened.")

    def write_data(self, data):
        self.file.write(data)

    def __del__(self):
        self.file.close()
        print("File closed.")

# Create object
handler = FileHandler("example.txt")
handler.write_data("Hello, world!")

# Delete object manually (for demo purposes)
del handler
# Out:
# File opened.
# File closed.

# %% [markdown]
# **6. What is the difference between import and from ... import in Python?**
#
# - Both import and from ... import are used to bring external modules or functions into your current Python program, but they work slightly differently in terms of scope, readability, and namespace usage.
#
# - import module :
#
#  - This imports the entire module and requires you to prefix its functions or classes with the module name.
#  - Advantage: Avoids naming conflicts
#  - Disadvantage: Slightly longer to type
#
# - from module import name :
#
#  - This imports a specific function, class, or variable directly, so you can use it without the module prefix.
#  - Advantage: Cleaner and shorter code
#  - Disadvantage: If you import many items, it may cause naming conflicts or reduce clarity.
#
# - from module import * :
#
#  - This imports everything from the module (not recommended).
#  - Not recommended in real-world projects, especially in large codebases, because it:
#
#  - Pollutes the namespace
#
#  - Makes it harder to know where functions come from
#
# - Example :

# %%
import math

print(math.sqrt(16))  # ✅ Access via module name
# Out:
# 4.0

# %%
from math import sqrt

print(sqrt(16))  # ✅ No module name needed
# Out:
# 4.0

# %%
from math import *

print(sqrt(25))  # Works, but unclear where sqrt came from
# Out:
# 5.0

# %% [markdown]
# **7. How can you handle multiple exceptions in Python?**
#
# - In Python, you can handle multiple exceptions in different ways using the try-except block. This is useful when you want to manage different types of errors that might occur in the same piece of code, each with its own response.
#
# - Method 1: Multiple except Blocks (Recommended)
#
#  - Handle each exception type with its own except block.
#  - Best when you want specific handling for each error.
#  - Example

# %%
try:
    number = int(input("Enter a number: "))
    result = 10 / number
    print("Result:", result)
except ZeroDivisionError:
    print("Cannot divide by zero.")
except ValueError:
    print("Invalid input. Please enter a number.")
# Out:
# Enter a number: 23
# Result: 0.43478260869565216

# %% [markdown]
# - Method 2: Single except Block Handling Multiple Exceptions
#
#  - You can catch multiple exceptions in one line using a tuple:
#  - Good for common handling of multiple exceptions.
#
# - Example :

# %%
try:
    value = int("abc")  # Will raise ValueError
    result = 10 / 0      # Will raise ZeroDivisionError
except (ZeroDivisionError, ValueError) as e:
    print("An error occurred:", e)
# Out:
# An error occurred: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# - Method 3: Generic except Block (Use with caution)
#
#  - Catch any exception, but less precise:
#  - Not recommended unless you’re logging errors or in production-safe wrappers.
#  - Doesn't help with debugging since you lose control over what went wrong.
#
# - Example :

# %%
try:
    risky_code()
except Exception as e:
    print("Something went wrong:", e)
# Out:
# Something went wrong: name 'risky_code' is not defined

# %% [markdown]
# - Bonus : Using else and finally with multiple exceptions

# %%
try:
    x = int(input("Enter a number: "))
    print("Square:", x * x)
except ValueError:
    print("Invalid input!")
else:
    print("No errors occurred.")
finally:
    print("Program finished.")
# Out:
# Enter a number: 78
# Square: 6084
# No errors occurred.
# Program finished.

# %% [markdown]
# **8. What is the purpose of the with statement when handling files in Python?**
#
# - The with statement in Python is used to manage resources like files in a clean, safe, and efficient way. It ensures that the file is automatically closed once you're done with it—even if an error occurs during the file operation.
#
# - Why use with?
#
#  - Automatically handles opening and closing files.
#
#  - Prevents file leaks (e.g., leaving a file open).
#
#  - Makes code cleaner and more readable.
#
#  - Reduces the need for explicit try-finally blocks.
#
# - Example :

# %%
# Create the file first
with open("data.txt", "w") as f:
    f.write("Hello, World!\nThis is a sample text file for reading in Python.")

# Now read the file using both methods
# Method 1: Manual open + close
file = open("data.txt", "r")
try:
    content = file.read()
    print("Manual read:\n", content)
finally:
    file.close()

# Method 2: With statement
with open("data.txt", "r") as file:
    content = file.read()
    print("With statement read:\n", content)
# Out:
# Manual read:
#  Hello, World!
# This is a sample text file for reading in Python.
# With statement read:
#  Hello, World!
# This is a sample text file for reading in Python.

# %% [markdown]
# **9. What is the difference between multithreading and multiprocessing?**
#
# - Multithreading and Multiprocessing are two ways to achieve concurrent execution in Python, but they differ in how they use system resources and handle tasks.
#
#  **1. Multithreading**
#
#  - Multithreading uses multiple threads within a single process. All threads share the same memory space.
#
#  - Best for :
#
#    - I/O-bound tasks (like file reading, web scraping, network calls)
#
#    - Tasks where the CPU is mostly idle waiting for external events
#
#  - Limitation :
#
#    - Python’s Global Interpreter Lock (GIL) prevents multiple threads from executing Python bytecode in parallel, limiting its use for CPU-heavy work.
#
# - Example :

# %%
import threading

def print_numbers():
    for i in range(5):
        print("Thread:", i)

t1 = threading.Thread(target=print_numbers)
t1.start()
t1.join()
# Out:
# Thread: 0
# Thread: 1
# Thread: 2
# Thread: 3
# Thread: 4

# %% [markdown]
#   2. Multiprocessing
#
#    - Multiprocessing uses multiple processes, each with its own memory space. These processes run in true parallelism (especially on multi-core CPUs).
#
#    - Best for :
#
#       - CPU-bound tasks (like data processing, computations)
#
#       - Tasks that require real parallel execution
#
#    - Benefit :
#
#       - Not limited by the GIL
#
#       - More reliable for parallel CPU-intensive operations
#
#
# - Example :

# %%
import multiprocessing

def print_numbers():
    for i in range(5):
        print("Process:", i)

p1 = multiprocessing.Process(target=print_numbers)
p1.start()
p1.join()
# Out:
# Process: 0
# Process: 1
# Process: 2
# Process: 3
# Process: 4

# %% [markdown]
# **10. What are the advantages of using logging in a program?**
#
# - Using Python’s logging module offers powerful benefits compared to simple print() statements. It’s a best practice for any real-world software project, especially as code complexity grows.
#
#  1. Helps in Debugging :
#
#    - Logging records what your program is doing step-by-step, making it easier to trace the source of bugs.
#
#  2. Categorized Severity Levels :
#
#    - You can label messages by importance:
#    - DEBUG, INFO, WARNING, ERROR, CRITICAL
#
#    - This helps you filter what messages to see during development vs production.
#
#  3. Saves Logs to Files
#
#    - Instead of cluttering the console, logs can be saved to a file
#
#    - Useful for:
#
#       - Audit trails
#
#       - Error tracking after deployment
#
#       - Long-term monitoring
#
#  4. Better than print() for Production :
#
#    - print() is fine for quick testing
#
#    - logging is configurable, clean, and maintainable
#
#    - You can easily turn it off, change log format, or redirect logs without changing code logic
#
#  5. Supports Multi-threaded and Multi-process Environments :
#
#    - Logging is thread-safe and can be used reliably in concurrent applications.
#
#  6. Customizable Output :
#
#    - You can format timestamps, log levels, function names, etc.
#
#  7. Enables Alerting and Monitoring :
#
#    - Advanced logging setups can integrate with:
#
#    - Email alerts
#
#    - Cloud log aggregators (like Logstash, ELK, Datadog)
#
#    - Crash reporting tools
# - Example :

# %%
import logging

# Set up logging configuration
logging.basicConfig(
    level=logging.DEBUG,  # Set minimum log level
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# Sample messages with different severity levels
logging.debug("This is a DEBUG message (used for troubleshooting).")
logging.info("This is an INFO message (used to show general information).")
logging.warning("This is a WARNING message (something unexpected happened, but not critical).")
logging.error("This is an ERROR message (a serious problem occurred).")
logging.critical("This is a CRITICAL message (very serious error).")
# Out:
# WARNING:root:This is a WARNING message (something unexpected happened, but not critical).
# ERROR:root:This is an ERROR message (a serious problem occurred).
# CRITICAL:root:This is a CRITICAL message (very serious error).

# %% [markdown]
# **11. What is memory management in Python?**
#
# - Memory management in Python refers to how Python allocates, uses, and reclaims memory used by variables, data structures, and objects during a program’s execution.
# Python handles memory management automatically, so you usually don’t have to manually allocate or deallocate memory (unlike C or C++).
#
# - Key Components of Memory Management in Python:
#
#   1. Automatic Garbage Collection
#
#     - Python uses a garbage collector to automatically detect and delete objects that are no longer used (unreachable).
#
#     - It uses reference counting and cyclic garbage collection to track and free memory.
#
#   2. Reference Counting
#
#     - Every object in Python has a reference count (how many variables point to it).
#
#     - When the count reaches zero, the memory is released.
#
#   3. Cyclic Garbage Collector
#
#     - Python can handle circular references (e.g., objects referencing each other), which simple reference counting can’t clean up.
#
#   4. Memory Pools (via PyMalloc)
#
#     - Python uses a private heap and a memory pool manager (PyMalloc).
#
#     - It reuses memory internally for efficiency.
#
#   5. Manual Garbage Control (if needed)
#
#     - You can interact with the garbage collector manually using the gc module:
#
#   6. Why It Matters:
#
#     - Makes Python easier and safer to use (no memory leaks or manual freeing like C/C++).
#
#     - Ensures efficient use of memory resources in long-running applications.
#
#     - Helps you write cleaner, bug-free code.
#
# - Example :

# %%
import sys
import gc

class Sample:
    def __init__(self, name):
        self.name = name
        print(f"{self.name} created")

    def __del__(self):
        print(f"{self.name} deleted")

# Reference Counting Example
obj = Sample("ObjectA")
print("Reference Count:", sys.getrefcount(obj))  # +1 because getrefcount also creates a temp reference

# Create more references
ref1 = obj
ref2 = obj

print("Reference Count after more refs:", sys.getrefcount(obj))

# Delete references
del ref1
print("Reference Count after deleting ref1:", sys.getrefcount(obj))

del ref2
print("Reference Count after deleting ref2:", sys.getrefcount(obj))

del obj  # Now no references remain → __del__ will be called
# Out:
# ObjectA created
# Reference Count: 2
# Reference Count after more refs: 4
# Reference Count after deleting ref1: 3
# Reference Count after deleting ref2: 2
# ObjectA deleted

# %% [markdown]
# **12. What are the basic steps involved in exception handling in Python?**
#
# - Python's exception handling allows you to gracefully handle runtime errors so your program doesn’t crash abruptly.
#
# - Basic Steps in Exception Handling:
#
#   1. Try Block
#
#    - Wrap the code that might raise an exception in a try block.
#
#   2. Except Block
#
#    - Catch and handle the exception using except.
#
#   3. Optional Else Block
#
#    - Runs only if no exception is raised in the try block.
#
#   4. Optional Finally Block
#
#    - Always runs no matter what—used to release resources like files or DB connections.
#
# - Example:

# %%
def divide_numbers(a, b):
    try:
        result = a / b
    except ZeroDivisionError:
        print("Error: Division by zero is not allowed.")
    else:
        print("Division result:", result)
    finally:
        print("This block always executes.")

divide_numbers(10, 2)
divide_numbers(5, 0)
# Out:
# Division result: 5.0
# This block always executes.
# Error: Division by zero is not allowed.
# This block always executes.

# %% [markdown]
# **13. Why is memory management important in Python?**
#
# - Memory management is a crucial part of writing efficient and reliable Python programs, especially as applications grow in complexity or run for long periods (like servers, data pipelines, or real-time dashboards).
#
# - Reasons Why Memory Management is Important:
#  1. Prevents Memory Leaks
#    - When memory is not released properly, it can build up over time.
#
#    - Memory leaks slow down your program and may eventually crash it.
#
#    - Python’s garbage collector helps prevent this—but you still need to write memory-efficient code.
#
#    - Example: Keeping unused large data structures in memory for no reason.
#
#  2. Improves Performance
#
#     - Efficient use of memory leads to faster execution.
#
#     - Less memory usage means fewer slowdowns due to swapping or memory overhead.
#
#     - Especially important in large datasets, machine learning models, or API servers handling multiple users.
#
#  3. Ensures Scalability
#
#     - Proper memory management allows your application to handle more users or data without crashing.
#
#     - Helps apps scale without running out of system resources.
#
#  4. Avoids Crashes or Out-of-Memory Errors
#
#     - If you consume too much RAM, your Python process may crash or freeze.
#
#     - For long-running applications (e.g., web servers, background jobs), stability is key.
#
#  5. Better Resource Allocation
#
#     - Efficient code leaves memory available for other processes or services on the same system.
#
#     - This is important in shared environments, such as cloud servers or containers.
#
# - Example :

# %%
import time
import sys

data = []

print("Starting memory-heavy operation...")
for i in range(10_000_000):
    data.append(str(i) * 100)  # creates huge strings and stores all in memory

print("Total elements:", len(data))
print("Estimated memory used by list:", sys.getsizeof(data), "bytes")

time.sleep(5)  # pause to observe memory in task manager
# Out:
# Starting memory-heavy operation...
# Total elements: 10000000
# Estimated memory used by list: 89095160 bytes

# %%
import time
import sys

def data_generator(n):
    for i in range(n):
        yield str(i) * 100

print("Starting memory-efficient operation...")
count = 0

for item in data_generator(10_000_000):
    # Process the item (simulate by incrementing count)
    count += 1

print("Total processed items:", count)
print("No massive memory usage here!")

time.sleep(5)
# Out:
# Starting memory-efficient operation...
# Total processed items: 10000000
# No massive memory usage here!

# %% [markdown]
# **14. What is the role of try and except in exception handling?**
#
# - In Python, the try and except blocks are used to handle runtime errors gracefully without crashing the program.
#
# - Purpose:
#
#  - try: Defines a block of code to test for errors.
#
#  - except: Defines a block of code to handle the error if it occurs.
#
#  - This structure allows the program to continue running, even if an error is raised.
#
# - Why Use It?
#
#  - Prevents your program from stopping unexpectedly.
#
#  - Allows you to display helpful error messages.
#
#  - Enables fallback logic or recovery steps.
#
# - Example:

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
    print("Result is:", result)
except ValueError:
    print("Please enter a valid number.")
except ZeroDivisionError:
    print("You cannot divide by zero.")
# Out:
# Enter a number: 87
# Result is: 0.11494252873563218

# %% [markdown]
# **15. How does Python's garbage collection system work?**
#
# - Python’s garbage collection system is responsible for automatically managing memory. It reclaims memory from objects that are no longer in use, so developers don’t have to manually free memory like in C or C++.
#
# - Key Concepts Behind Python Garbage Collection:
#  1. Reference Counting
#
#    - Every object in Python has a reference count—a number that shows how many references point to it.
#
#    - When an object’s reference count drops to zero, it means no part of your program needs it anymore.
#
#    - Python immediately deletes such objects and reclaims the memory.
#
#  2. Cyclic Garbage Collector
#
#    - Reference counting fails when objects refer to each other in a cycle. For example:
#
#    - These two objects reference each other, so their reference counts never reach zero—even if the program doesn’t use them anymore.
#
#    - Python’s cyclic garbage collector solves this problem by periodically scanning for groups of objects that are only reachable by each other, and deletes them.
#
#  3. Garbage Collection Module (gc)
#
#    - You can manually interact with the garbage collector using the gc module:
#
# - Example:

# %%
class Demo:
    def __del__(self):
        print("Deleted:", self)

a = Demo()
b = Demo()

a.ref = b
b.ref = a

# Remove references
del a
del b

# Force garbage collection
import gc
gc.collect()
# Out:
# Deleted: <__main__.Demo object at 0x7891bc3b70d0>
# Deleted: <__main__.Demo object at 0x7891bc3b6590>
# 101

# %% [markdown]
# **16. What is the purpose of the else block in exception handling?**
#
# - In Python, the else block in exception handling is optional and runs only if no exception was raised in the try block.
#
# - Purpose:
#
#  - It lets you separate code that should run only if everything in try goes well.
#
#  - Helps write cleaner and more readable code by keeping success logic separate from error handling.
#
# - Think of it this way:
#
#  - try: Run risky code.
#
#  - except: Handle errors if they happen.
#
#  - else: Run only if there were no errors.
#
#  - finally: Run no matter what.
#
# - When to Use else:
#
#  - When you want to keep the main logic separate from the exception logic.
#
#  - When the try block includes only the risky operation, and the rest of the logic should only run if no error occurs.
#
# - Example:

# %%
def divide(a, b):
    try:
        result = a / b
    except ZeroDivisionError:
        print("Cannot divide by zero.")
    else:
        print("Division successful. Result:", result)
    finally:
        print("Operation complete.")

divide(10, 2)
divide(5, 0)
# Out:
# Division successful. Result: 5.0
# Operation complete.
# Cannot divide by zero.
# Operation complete.

# %% [markdown]
# **17. What are the common logging levels in Python?**
#
# - Python provides a built-in logging module to help developers track events during program execution. It uses logging levels to indicate the severity or purpose of a log message.
#
# - Common Logging Levels (from lowest to highest severity):
#
#  1. DEBUG
#    - Detailed info, used for diagnosing problems during development.
#
#  2. INFO
#    - General info about program execution (e.g., startup, shutdown, actions).
#
#  3. WARNING
#    - Indicates something unexpected, but the program is still running.
#
#  4. ERROR
#    - A more serious problem—something failed.
#
#  5. CRITICAL
#    - Very serious error—may prevent the program from continuing.
#
# - Example :

# %%
import logging

# Configure logging
logging.basicConfig(level=logging.DEBUG)

# Log messages at all levels
logging.debug("Debugging info")
logging.info("ℹProgram started successfully")
logging.warning("This is a warning")
logging.error("An error occurred")
logging.critical("Critical system failure")
# Out:
# WARNING:root:This is a warning
# ERROR:root:An error occurred
# CRITICAL:root:Critical system failure

# %% [markdown]
# **18. What is the difference between os.fork() and multiprocessing in Python?**
#
# - Both os.fork() and the multiprocessing module are used to create new processes in Python, but they differ greatly in platform support, ease of use, and level of abstraction.
#
#  1. os.fork()
#
#    - Low-level system call to create a child process.
#
#    - Only available on Unix/Linux/macOS (Not available on Windows).
#
#    - The child process is a copy of the parent process.
#
#    - Requires manual management of inter-process communication (IPC), exit codes, etc.
#
#    - Only works on Unix-based systems.
#
# - Example:

# %%
import os

pid = os.fork()

if pid == 0:
    print("This is the child process.")
else:
    print("This is the parent process.")
# Out:
# This is the parent process.
# This is the child process.

# %% [markdown]
#  2. multiprocessing Module
#
#   - Cross-platform (works on Windows, Linux, macOS).
#
#   - High-level, object-oriented API to create and manage processes.
#
#   - Automatically handles process creation, communication (Queue, Pipe), and synchronization (Lock, Event).
#
#   - Better suited for modern Python apps.
#
#   - This works the same way on all major operating systems.
#
#  - Example:

# %%
from multiprocessing import Process

def greet():
    print("Hello from a new process!")

p = Process(target=greet)
p.start()
p.join()
# Out:
# Hello from a new process!

# %% [markdown]
# **19. What is the importance of closing a file in Python?**
#
# - Closing a file in Python is critical for ensuring data integrity, freeing up system resources, and avoiding file corruption. When you open a file using open(), Python establishes a connection to the file on disk, which must be properly closed once you're done using it.
#
# - Why Closing a File Is Important:
#  1. Flushes Data to Disk
#
#    - When writing to a file, data is often stored in a temporary buffer.
#
#    - file.close() flushes this buffer—ensuring all data is written to disk.
#
#    - If you forget to close the file, you may lose some data.
#
#  2. Releases System Resources
#
#    - Open files consume system resources (file descriptors).
#
#    - Leaving files open can cause resource leaks, especially in loops or server applications.
#
#  3. Prevents Data Corruption
#
#    - An unclosed file may lead to corrupted content, especially when multiple programs are accessing the same file.
#
#  4. Avoids File Access Errors
#
#    - On some systems, a file can't be read or written by another process until it's closed.
#
# - Example:

# %%
with open("example.txt", "w") as f:
    f.write("Hello, World!")
# File is automatically closed when 'with' block ends

# %% [markdown]
# **20. What is the difference between file.read() and file.readline() in Python?**
#
# - Both file.read() and file.readline() are methods used to read content from a file, but they serve different purposes based on how much content you want to read at once.
#
#  1. file.read()
#
#    - Reads the entire content of the file into a single string.
#
#    - Used when you want to process the whole file at once.
#
#    - Can consume a lot of memory for large files.
#
#  - Example:

# %%
with open("example.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# Hello, World!

# %% [markdown]
#  2. file.readline()
#
#   - Reads one line at a time (until \n or end-of-file).
#
#   - Used when you want to process files line-by-line.
#
#   - Memory-efficient, especially for large files.
#
#  - Example:

# %%
with open("example.txt", "r") as file:
    line1 = file.readline()
    line2 = file.readline()
    print("Line 1:", line1)
    print("Line 2:", line2)
# Out:
# Line 1: Hello, World!
# Line 2:

# %% [markdown]
# **21. What is the logging module in Python used for?**
#
# - The logging module in Python is used for tracking events that happen when some software runs. It allows developers to:
#
# - Key Uses:
#
#  - Record events and errors – instead of using print(), logging helps record debug messages, warnings, errors, and critical issues.
#
#  - Debug code systematically by keeping logs.
#
#  - Store logs in files for later analysis.
#
#  - Control message level (e.g., DEBUG, INFO, WARNING, ERROR, CRITICAL).
#
#  - Route logs to different destinations like files, the console, or external systems.
#
#  - This will create a file app.log with the log messages.
#
# - Why not just use print()?
#
#  - print() is good for temporary testing, but:
#
#  - It's hard to filter or format.
#
#  - It doesn't support log levels.
#
#  - It can clutter output.
#
#  - It can't log to multiple places (e.g., file + console).
#
# - Example:

# %%
import logging

# Set up basic configuration
logging.basicConfig(level=logging.DEBUG, filename='app.log', filemode='w',
                    format='%(name)s - %(levelname)s - %(message)s')

logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning")
logging.error("This is an error message")
logging.critical("This is critical")
# Out:
# WARNING:root:This is a warning
# ERROR:root:This is an error message
# CRITICAL:root:This is critical

# %% [markdown]
# **22. What is the os module in Python used for in file handling?**
#
# - The os module in Python provides a way of using operating system dependent functionality like reading or writing to the file system. It is used in file handling to perform various tasks that go beyond reading/writing file content — such as creating, deleting, moving, renaming files and directories, checking if files exist, and navigating the file system.
#
# - Key Functions of os in File Handling:
#
# | Function                               | Description                                          |
# | -------------------------------------- | ---------------------------------------------------- |
# | `os.path.exists(path)`                 | Checks if the given path (file or directory) exists. |
# | `os.mkdir(path)` / `os.makedirs(path)` | Creates a new directory or nested directories.       |
# | `os.remove(path)`                      | Deletes a file.                                      |
# | `os.rename(src, dst)`                  | Renames or moves a file.                             |
# | `os.getcwd()`                          | Returns the current working directory.               |
# | `os.chdir(path)`                       | Changes the current working directory.               |
# | `os.listdir(path)`                     | Lists all files and directories in the given path.   |
# | `os.path.isfile(path)`                 | Checks if the path is a file.                        |
# | `os.path.isdir(path)`                  | Checks if the path is a directory.                   |
#
# - Example:

# %%
import os

# Check if a file exists
if os.path.exists("data.txt"):
    print("File found: data.txt")

    # Read file content
    with open("data.txt", "r") as file:
        content = file.read()
        print("File content:\n", content)

    # Rename the file
    os.rename("data.txt", "data_backup.txt")
    print("File has been renamed to data_backup.txt")

    # Delete the renamed file
    os.remove("data_backup.txt")
    print("Backup file deleted.")
else:
    print("data.txt does not exist.")
# Out:
# File found: data.txt
# File content:
#  Hello, World!
# This is a sample text file for reading in Python.
# File has been renamed to data_backup.txt
# Backup file deleted.

# %% [markdown]
# **23. What are the challenges associated with memory management in Python?**
#
# - Challenges Associated with Memory Management in Python
#
# - Python does a lot of memory management automatically through its built-in garbage collector and dynamic memory allocation. However, developers can still face several challenges:
#
#  1. Memory Leaks
#
#    - Even though Python has a garbage collector, memory leaks can still happen — especially when objects are unintentionally kept alive (e.g., through global variables, circular references, or improperly managed caches).
#
#  2. Circular References
#
#    - When two or more objects reference each other (like in a parent-child relationship), Python's reference counting alone cannot handle their cleanup. Although Python’s gc module can detect and collect these, it's not always efficient.
#
#  3. High Memory Usage
#
#    - Python uses more memory compared to languages like C or Java because of its high-level abstractions and object overhead. This can be a problem for memory-sensitive applications (e.g., mobile or embedded systems).
#
#  4. Inefficient Data Structures
#
#    - Using inappropriate data structures (e.g., lists where set or dict should be used) can increase memory usage unnecessarily.
#
#  5. Unreleased Resources
#
#    - If files, sockets, or other system resources aren't explicitly closed (or used outside of with blocks), they may remain in memory longer than needed.
#
#  6. Mutable Default Arguments
#
#    - Using mutable default arguments like lists or dictionaries in functions can accidentally accumulate data over multiple function calls, leading to unexpected memory behavior.
#
# - Example of a Circular Reference Causing a Memory Leak:

# %%
import gc

class Node:
    def __init__(self):
        self.ref = None

# Create two nodes referencing each other
a = Node()
b = Node()
a.ref = b
b.ref = a

# Remove references from variables
a = None
b = None

# Force garbage collection
unreachable = gc.collect()
print(f"Unreachable objects collected: {unreachable}")
# Out:
# Unreachable objects collected: 43

# %% [markdown]
# **24. How do you raise an exception manually in Python?**
#
# - In Python, you can raise an exception manually using the raise keyword. This is useful when you want to signal that something went wrong in your code — either due to invalid input, failed condition checks, or business logic violations.
#
# - Syntax:
#
#  - raise ExceptionType("Optional error message")
#
# - Here:
#
#  - ExceptionType can be any built-in exception like ValueError, TypeError, or a custom one you define.
#
#  - The optional string is a message describing the error.
#
# - Common Built-in Exceptions You Might Raise:
#
#  - ValueError: For invalid values
#
#  - TypeError: For wrong data types
#
#  - ZeroDivisionError: For illegal division operations
#
#  - RuntimeError: For unexpected behavior during execution
#
#  - CustomException: User-defined class inherited from Exception
#
# - Example: Raising a ValueError Manually

# %%
def set_age(age):
    if age < 0:
        raise ValueError("Age cannot be negative!")
    print(f"Age is set to {age}")

set_age(25)     # Works fine
set_age(-5)     # Raises ValueError
# Out:
# Age is set to 25
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-10-1999511540.py in <cell line: 0>()
#       5
#       6 set_age(25)     # Works fine
# ----> 7 set_age(-5)     # Raises ValueError
#
# /tmp/ipython-input-10-1999511540.py in set_age(age)
#       1 def set_age(age):
#       2     if age < 0:
# ----> 3         raise ValueError("Age cannot be negative!")
#       4     print(f"Age is set to {age}")
#       5
#
# ValueError: Age cannot be negative!

# %% [markdown]
# **25. Why is it important to use multithreading in certain applications?**
#
# - Multithreading is a programming technique that allows multiple threads to run concurrently within a single process. In Python, it’s especially useful for I/O-bound applications — where tasks spend time waiting (e.g., reading files, waiting for network responses).
#
# - Using multithreading improves the responsiveness and efficiency of programs that need to handle many slow I/O operations at once, even though Python’s Global Interpreter Lock (GIL) limits true parallelism in CPU-bound tasks.
#
# - Key Reasons to Use Multithreading:
#
#  1. Improved Responsiveness
#
#    - Applications like GUIs or web servers stay responsive even while performing background tasks (e.g., downloads, file operations).
#
#  2. Concurrent I/O Operations
#
#    - Useful when waiting for APIs, user input, disk access, or database responses.
#
#  3. Better Resource Utilization
#
#    - While one thread waits, another can execute — keeping the program productive.
#
#  4. Simpler Than Multiprocessing (in I/O cases)
#
#    - For lightweight tasks, threading is easier to implement and manage than multiprocessing.
#
#  5. Efficient for Network Applications
#
#    - E.g., chat servers, real-time dashboards, downloaders.
#
# - When NOT to Use Multithreading:
#
#  - In CPU-bound tasks (e.g., image processing, heavy computation), because the GIL limits Python threads from running in true parallel.
#
#  - In such cases, multiprocessing is better.
#
# - Example: Multithreading with I/O

# %%
import threading
import time

def download_file(file_id):
    print(f"Starting download for file {file_id}")
    time.sleep(2)  # Simulate time delay
    print(f"Download complete for file {file_id}")

# Create two threads
thread1 = threading.Thread(target=download_file, args=(1,))
thread2 = threading.Thread(target=download_file, args=(2,))

# Start both threads
thread1.start()
thread2.start()

# Wait for both threads to finish
thread1.join()
thread2.join()

print("All downloads completed.")
# Out:
# Starting download for file 1Starting download for file 2
#
# Download complete for file 2
# Download complete for file 1
# All downloads completed.

# %% [markdown]
# # **Practical Questions**

# %% [markdown]
# **1. How can you open a file for writing in Python and write a string to it?**

# %%
with open("example1.txt", "w") as file:
    file.write("This is a sample text written to the file.")

# %% [markdown]
# **2. Write a Python program to read the contents of a file and print each line.**

# %%
with open("example1.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# This is a sample text written to the file.

# %% [markdown]
# **3. How would you handle a case where the file doesn't exist while trying to open it for reading?**

# %%
try:
    with open("non_existent_file.txt", "r") as file:
        print(file.read())
except FileNotFoundError:
    print("Error: The file does not exist.")
# Out:
# Error: The file does not exist.

# %% [markdown]
# **4. Write a Python script that reads from one file and writes its content to another file.**

# %%
with open("example1.txt", "r") as source_file:
    content = source_file.read()

with open("example2.txt", "w") as target_file:
    target_file.write(content)

# %% [markdown]
# **5. How would you catch and handle division by zero error in Python?**

# %%
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero.")
# Out:
# Cannot divide by zero.

# %% [markdown]
# **6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.**

# %%
import logging

logging.basicConfig(filename='error_log.txt', level=logging.ERROR)

try:
    result = 10 / 0
except ZeroDivisionError as e:
    logging.error(f"Error occurred: {e}")
# Out:
# ERROR:root:Error occurred: division by zero

# %% [markdown]
# **7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module.**

# %%
import logging

logging.basicConfig(level=logging.DEBUG)

logging.info("This is an INFO message.")
logging.warning("This is a WARNING message.")
logging.error("This is an ERROR message.")
# Out:
# WARNING:root:This is a WARNING message.
# ERROR:root:This is an ERROR message.

# %% [markdown]
# **8. Write a program to handle a file opening error using exception handling.**

# %%
try:
    file = open("non_existent.txt", "r")
except IOError:
    print("Failed to open the file.")
# Out:
# Failed to open the file.

# %% [markdown]
# **9. How can you read a file line by line and store its content in a list in Python?**

# %%
with open("example1.txt", "r") as file:
    lines = file.readlines()

print(lines)
# Out:
# ['This is a sample text written to the file.']

# %% [markdown]
# **10. How can you append data to an existing file in Python?**

# %%
with open("example1.txt", "a") as file:
    file.write("\nThis is an appended line.")

# %% [markdown]
# **11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.**

# %%
# Define a sample dictionary
student_scores = {
    "Alice": 85,
    "Bob": 92,
    "Charlie": 78
}

# Try accessing a key that may not exist
try:
    score = student_scores["David"]  # 'David' is not in the dictionary
    print(f"David's score is {score}")
except KeyError:
    print("Error: The key 'David' does not exist in the dictionary.")
# Out:
# Error: The key 'David' does not exist in the dictionary.

# %% [markdown]
# **12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions.**

# %%
try:
    # Trigger a ValueError
    number = int("abc")  # This will fail because "abc" is not a number

    # Trigger a ZeroDivisionError
    result = 10 / 0

    # Trigger a KeyError
    my_dict = {"a": 1}
    print(my_dict["b"])

except ValueError:
    print("Caught a ValueError: Cannot convert string to integer.")

except ZeroDivisionError:
    print("Caught a ZeroDivisionError: Division by zero is not allowed.")

except KeyError:
    print("Caught a KeyError: The key does not exist in the dictionary.")

except Exception as e:
    print(f"Caught a general exception: {e}")
# Out:
# Caught a ValueError: Cannot convert string to integer.

# %% [markdown]
# **13. How would you check if a file exists before attempting to read it in Python?**

# %%
import os

filename = "example.txt"

if os.path.exists(filename):
    with open(filename, 'r') as file:
        content = file.read()
        print("File contents:\n", content)
else:
    print(f"The file '{filename}' does not exist.")
# Out:
# File contents:
#  Hello, World!

# %%
# Executable Code Using pathlib Module (Recommended for newer Python versions)

from pathlib import Path

file_path = Path("example.txt")

if file_path.exists():
    with open(file_path, 'r') as file:
        content = file.read()
        print("File contents:\n", content)
else:
    print(f"The file '{file_path}' does not exist.")
# Out:
# File contents:
#  Hello, World!

# %% [markdown]
# **14. Write a program that uses the logging module to log both informational and error messages.**

# %%
import logging

# Configure logging
logging.basicConfig(
    filename='app.log',            # Log file name
    level=logging.DEBUG,           # Set minimum logging level
    format='%(asctime)s - %(levelname)s - %(message)s'  # Log format
)

# Log informational message
logging.info("The program started successfully.")

# Simulate a function that might raise an error
try:
    x = 10 / 0
except ZeroDivisionError as e:
    logging.error("An error occurred: Division by zero.")

# Another info message after the error
logging.info("Program completed with some handled exceptions.")
# Out:
# ERROR:root:An error occurred: Division by zero.

# %% [markdown]
# **15. Write a Python program that prints the content of a file and handles the case when the file is empty.**

# %%
filename = "example.txt"  # Replace with your filename

try:
    with open(filename, 'r') as file:
        content = file.read()
        if not content:
            print("The file is empty.")
        else:
            print("File contents:\n")
            print(content)

except FileNotFoundError:
    print(f"The file '{filename}' does not exist.")
# Out:
# File contents:
#
# Hello, World!

# %% [markdown]
# **16. Demonstrate how to use memory profiling to check the memory usage of a small program?**

# %%
# Run this using: pip install memory-profiler
from memory_profiler
import profile

@profile
def create_list():
    my_list = [i for i in range(100000)]
    return my_list

create_list()

# %% [markdown]
# **17. Write a Python program to create and write a list of numbers to a file, one number per line.**

# %%
# List of numbers to write
numbers = [10, 20, 30, 40, 50]

# File to write into
filename = "numbers.txt"

try:
    with open(filename, 'w') as file:
        for number in numbers:
            file.write(str(number) + '\n')
    print(f"Successfully wrote {len(numbers)} numbers to {filename}.")

except Exception as e:
    print("An error occurred:", e)
# Out:
# Successfully wrote 5 numbers to numbers.txt.

# %% [markdown]
# **18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?**

# %%
import logging
from logging.handlers import RotatingFileHandler

# Create a logger
logger = logging.getLogger("MyRotatingLogger")
logger.setLevel(logging.DEBUG)  # Set logging level to capture all types of logs

# Set up rotating handler - logs rotate after 1MB, keep 3 backup logs
handler = RotatingFileHandler(
    "rotating_log.log", maxBytes=1 * 1024 * 1024, backupCount=3
)

# Format for logs
formatter = logging.Formatter(
    '%(asctime)s - %(levelname)s - %(message)s'
)
handler.setFormatter(formatter)

# Add handler to logger
logger.addHandler(handler)

# Generate logs for testing
for i in range(10000):
    logger.info(f"This is log message number {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:MyRotatingLogger:This is log message number 5000
# INFO:MyRotatingLogger:This is log message number 5001
# INFO:MyRotatingLogger:This is log message number 5002
# INFO:MyRotatingLogger:This is log message number 5003
# INFO:MyRotatingLogger:This is log message number 5004
# INFO:MyRotatingLogger:This is log message number 5005
# INFO:MyRotatingLogger:This is log message number 5006
# INFO:MyRotatingLogger:This is log message number 5007
# INFO:MyRotatingLogger:This is log message number 5008
# INFO:MyRotatingLogger:This is log message number 5009
# INFO:MyRotatingLogger:This is log message number 5010
# INFO:MyRotatingLogger:This is log message number 5011
# INFO:MyRotatingLogger:This is log message number 5012
# INFO:MyRotatingLogger:This is log message number 5013
# INFO:MyRotatingLogger:This is log message number 5014
# INFO:MyRotatingLogger:This is log message number 5015
# INFO:MyRotatingLogger:This is log message number 5016
# INFO:MyRotatingLogger:This is log message number 5017
# INFO:MyRotatingLogger:This is log message number 5018
# INFO:MyRotatingLogger:This is log message number 5019
# INFO:MyRotatingLogger:This is log message number 5020
# INFO:MyRotatingLogger:This is log message number 5021
# INFO:MyRotatingLogger:This is log message number 5022
# INFO:MyRotatingLogger:This is log message number 5023
# INFO:MyRotatingLogger:This is log message number 5024
# INFO:MyRotatingLogger:This is log message number 5025
# INFO:MyRotatingLogger:This is log message number 5026
# INFO:MyRotatingLogger:This is log message number 5027
# INFO:MyRotatingLogger:This is log message number 5028
# INFO:MyRotatingLogger:This is log message number 5029
# INFO:MyRotatingLogger:This is log message number 5030
# INFO:MyRotatingLogger:This is log message number 5031
# INFO:MyRotatingLogger:This is log message number 5032
# INFO:MyRotatingLogger:This is log message number 5033
# INFO:MyRotatingLogger:This is log message number 5034
# INFO:MyRotatingLogger:This is log message number 5035
# INFO:MyRotatingLogger:This is log message number 5036
# INFO:MyRotatingLogger:This is log message number 5037
# INFO:MyRotatingLogger:This is log message number 5038
# INFO:MyRotatingLogger:This is log message number 5039
# INFO:MyRotatingLogger:This is log message number 5040
# INFO:MyRotatingLogger:This is log message number 5041
# INFO:MyRotatingLogger:This is log message number 5042
# INFO:MyRotatingLogger:This is log message number 5043
# INFO:MyRotatingLogger:This is log message number 5044
# INFO:MyRotatingLogger:This is log message number 5045
# INFO:MyRotatingLogger:This is log message number 5046
# INFO:MyRotatingLogger:This is log message number 5047
# INFO:MyRotatingLogger:This is log message number 5048
# INFO:MyRotatingLogger:This is log message number 5049
# INFO:MyRotatingLogger:This is log message number 5050
# INFO:MyRotatingLogger:This is log message number 5051
# INFO:MyRotatingLogger:This is log message number 5052
# INFO:MyRotatingLogger:This is log message number 5053
# INFO:MyRotatingLogger:This is log message number 5054
# INFO:MyRotatingLogger:This is log message number 5055
# INFO:MyRotatingLogger:This is log message number 5056
# INFO:MyRotatingLogger:This is log message number 5057
# INFO:MyRotatingLogger:This is log message number 5058
# INFO:MyRotatingLogger:This is log message number 5059
# INFO:MyRotatingLogger:This is log message number 5060
# INFO:MyRotatingLogger:This is log message number 5061
# INFO:MyRotatingLogger:This is log message number 5062
# INFO:MyRotatingLogger:This is log message number 5063
# INFO:MyRotatingLogger:This is log message number 5064
# INFO:MyRotatingLogger:This is log message number 5065
# INFO:MyRotatingLogger:This is log message number 5066
# INFO:MyRotatingLogger:This is log message number 5067
# INFO:MyRotatingLogger:This is log message number 5068
# INFO:MyRotatingLogger:This is log message number 5069
# INFO:MyRotatingLogger:This is log message number 5070
# INFO:MyRotatingLogger:This is log message number 5071
# INFO:MyRotatingLogger:This is log message number 5072
# INFO:MyRotatingLogger:This is log message number 5073
# INFO:MyRotatingLogger:This is log message number 5074
# INFO:MyRotatingLogger:This is log message number 5075
# INFO:MyRotatingLogger:This is log message number 5076
# INFO:MyRotatingLogger:This is log message number 5077
# INFO:MyRotatingLogger:This is log message number 5078
# INFO:MyRotatingLogger:This is log message number 5079
# INFO:MyRotatingLogger:This is log message number 5080
# INFO:MyRotatingLogger:This is log message number 5081
# INFO:MyRotatingLogger:This is log message number 5082
# INFO:MyRotatingLogger:This is log message number 5083
# INFO:MyRotatingLogger:This is log message number 5084
# INFO:MyRotatingLogger:This is log message number 5085
# INFO:MyRotatingLogger:This is log message number 5086
# INFO:MyRotatingLogger:This is log message number 5087
# INFO:MyRotatingLogger:This is log message number 5088
# INFO:MyRotatingLogger:This is log message number 5089
# INFO:MyRotatingLogger:This is log message number 5090
# INFO:MyRotatingLogger:This is log message number 5091
# INFO:MyRotatingLogger:This is log message number 5092
# INFO:MyRotatingLogger:This is log message number 5093
# INFO:MyRotatingLogger:This is log message number 5094
# INFO:MyRotatingLogger:This is log message number 5095
# INFO:MyRotatingLogger:This is log message number 5096
# INFO:MyRotatingLogger:This is log message number 5097
# INFO:MyRotatingLogger:This is log message number 5098
# INFO:MyRotatingLogger:This is log message number 5099
# INFO:MyRotatingLogger:This is log message number 5100
# INFO:MyRotatingLogger:This is log message number 5101
# INFO:MyRotatingLogger:This is log message number 5102
# INFO:MyRotatingLogger:This is log message number 5103
# INFO:MyRotatingLogger:This is log message number 5104
# INFO:MyRotatingLogger:This is log message number 5105
# INFO:MyRotatingLogger:This is log message number 5106
# INFO:MyRotatingLogger:This is log message number 5107
# INFO:MyRotatingLogger:This is log message number 5108
# INFO:MyRotatingLogger:This is log message number 5109
# INFO:MyRotatingLogger:This is log message number 5110
# INFO:MyRotatingLogger:This is log message number 5111
# INFO:MyRotatingLogger:This is log message number 5112
# INFO:MyRotatingLogger:This is log message number 5113
# INFO:MyRotatingLogger:This is log message number 5114
# INFO:MyRotatingLogger:This is log message number 5115
# INFO:MyRotatingLogger:This is log message number 5116
# INFO:MyRotatingLogger:This is log message number 5117
# INFO:MyRotatingLogger:This is log message number 5118
# INFO:MyRotatingLogger:This is log message number 5119
# INFO:MyRotatingLogger:This is log message number 5120
# INFO:MyRotatingLogger:This is log message number 5121
# INFO:MyRotatingLogger:This is log message number 5122
# INFO:MyRotatingLogger:This is log message number 5123
# INFO:MyRotatingLogger:This is log message number 5124
# INFO:MyRotatingLogger:This is log message number 5125
# INFO:MyRotatingLogger:This is log message number 5126
# INFO:MyRotatingLogger:This is log message number 5127
# INFO:MyRotatingLogger:This is log message number 5128
# INFO:MyRotatingLogger:This is log message number 5129
# INFO:MyRotatingLogger:This is log message number 5130
# INFO:MyRotatingLogger:This is log message number 5131
# INFO:MyRotatingLogger:This is log message number 5132
# INFO:MyRotatingLogger:This is log message number 5133
# INFO:MyRotatingLogger:This is log message number 5134
# INFO:MyRotatingLogger:This is log message number 5135
# INFO:MyRotatingLogger:This is log message number 5136
# INFO:MyRotatingLogger:This is log message number 5137
# INFO:MyRotatingLogger:This is log message number 5138
# INFO:MyRotatingLogger:This is log message number 5139
# INFO:MyRotatingLogger:This is log message number 5140
# INFO:MyRotatingLogger:This is log message number 5141
# INFO:MyRotatingLogger:This is log message number 5142
# INFO:MyRotatingLogger:This is log message number 5143
# INFO:MyRotatingLogger:This is log message number 5144
# INFO:MyRotatingLogger:This is log message number 5145
# INFO:MyRotatingLogger:This is log message number 5146
# INFO:MyRotatingLogger:This is log message number 5147
# INFO:MyRotatingLogger:This is log message number 5148
# INFO:MyRotatingLogger:This is log message number 5149
# INFO:MyRotatingLogger:This is log message number 5150
# INFO:MyRotatingLogger:This is log message number 5151
# INFO:MyRotatingLogger:This is log message number 5152
# INFO:MyRotatingLogger:This is log message number 5153
# INFO:MyRotatingLogger:This is log message number 5154
# INFO:MyRotatingLogger:This is log message number 5155
# INFO:MyRotatingLogger:This is log message number 5156
# INFO:MyRotatingLogger:This is log message number 5157
# INFO:MyRotatingLogger:This is log message number 5158
# INFO:MyRotatingLogger:This is log message number 5159
# INFO:MyRotatingLogger:This is log message number 5160
# INFO:MyRotatingLogger:This is log message number 5161
# INFO:MyRotatingLogger:This is log message number 5162
# INFO:MyRotatingLogger:This is log message number 5163
# INFO:MyRotatingLogger:This is log message number 5164
# INFO:MyRotatingLogger:This is log message number 5165
# INFO:MyRotatingLogger:This is log message number 5166
# INFO:MyRotatingLogger:This is log message number 5167
# INFO:MyRotatingLogger:This is log message number 5168
# INFO:MyRotatingLogger:This is log message number 5169
# INFO:MyRotatingLogger:This is log message number 5170
# INFO:MyRotatingLogger:This is log message number 5171
# INFO:MyRotatingLogger:This is log message number 5172
# INFO:MyRotatingLogger:This is log message number 5173
# INFO:MyRotatingLogger:This is log message number 5174
# INFO:MyRotatingLogger:This is log message number 5175
# INFO:MyRotatingLogger:This is log message number 5176
# INFO:MyRotatingLogger:This is log message number 5177
# INFO:MyRotatingLogger:This is log message number 5178
# INFO:MyRotatingLogger:This is log message number 5179
# INFO:MyRotatingLogger:This is log message number 5180
# INFO:MyRotatingLogger:This is log message number 5181
# INFO:MyRotatingLogger:This is log message number 5182
# INFO:MyRotatingLogger:This is log message number 5183
# INFO:MyRotatingLogger:This is log message number 5184
# INFO:MyRotatingLogger:This is log message number 5185
# INFO:MyRotatingLogger:This is log message number 5186
# INFO:MyRotatingLogger:This is log message number 5187
# INFO:MyRotatingLogger:This is log message number 5188
# INFO:MyRotatingLogger:This is log message number 5189
# INFO:MyRotatingLogger:This is log message number 5190
# INFO:MyRotatingLogger:This is log message number 5191
# INFO:MyRotatingLogger:This is log message number 5192
# INFO:MyRotatingLogger:This is log message number 5193
# INFO:MyRotatingLogger:This is log message number 5194
# INFO:MyRotatingLogger:This is log message number 5195
# INFO:MyRotatingLogger:This is log message number 5196
# INFO:MyRotatingLogger:This is log message number 5197
# INFO:MyRotatingLogger:This is log message number 5198
# INFO:MyRotatingLogger:This is log message number 5199
# INFO:MyRotatingLogger:This is log message number 5200
# INFO:MyRotatingLogger:This is log message number 5201
# INFO:MyRotatingLogger:This is log message number 5202
# INFO:MyRotatingLogger:This is log message number 5203
# INFO:MyRotatingLogger:This is log message number 5204
# INFO:MyRotatingLogger:This is log message number 5205
# INFO:MyRotatingLogger:This is log message number 5206
# INFO:MyRotatingLogger:This is log message number 5207
# INFO:MyRotatingLogger:This is log message number 5208
# INFO:MyRotatingLogger:This is log message number 5209
# INFO:MyRotatingLogger:This is log message number 5210
# INFO:MyRotatingLogger:This is log message number 5211
# INFO:MyRotatingLogger:This is log message number 5212
# INFO:MyRotatingLogger:This is log message number 5213
# INFO:MyRotatingLogger:This is log message number 5214
# INFO:MyRotatingLogger:This is log message number 5215
# INFO:MyRotatingLogger:This is log message number 5216
# INFO:MyRotatingLogger:This is log message number 5217
# INFO:MyRotatingLogger:This is log message number 5218
# INFO:MyRotatingLogger:This is log message number 5219
# INFO:MyRotatingLogger:This is log message number 5220
# INFO:MyRotatingLogger:This is log message number 5221
# INFO:MyRotatingLogger:This is log message number 5222
# INFO:MyRotatingLogger:This is log message number 5223
# INFO:MyRotatingLogger:This is log message number 5224
# INFO:MyRotatingLogger:This is log message number 5225
# INFO:MyRotatingLogger:This is log message number 5226
# INFO:MyRotatingLogger:This is log message number 5227
# INFO:MyRotatingLogger:This is log message number 5228
# INFO:MyRotatingLogger:This is log message number 5229
# INFO:MyRotatingLogger:This is log message number 5230
# INFO:MyRotatingLogger:This is log message number 5231
# INFO:MyRotatingLogger:This is log message number 5232
# INFO:MyRotatingLogger:This is log message number 5233
# INFO:MyRotatingLogger:This is log message number 5234
# INFO:MyRotatingLogger:This is log message number 5235
# INFO:MyRotatingLogger:This is log message number 5236
# INFO:MyRotatingLogger:This is log message number 5237
# INFO:MyRotatingLogger:This is log message number 5238
# INFO:MyRotatingLogger:This is log message number 5239
# INFO:MyRotatingLogger:This is log message number 5240
# INFO:MyRotatingLogger:This is log message number 5241
# INFO:MyRotatingLogger:This is log message number 5242
# INFO:MyRotatingLogger:This is log message number 5243
# INFO:MyRotatingLogger:This is log message number 5244
# INFO:MyRotatingLogger:This is log message number 5245
# INFO:MyRotatingLogger:This is log message number 5246
# INFO:MyRotatingLogger:This is log message number 5247
# INFO:MyRotatingLogger:This is log message number 5248
# INFO:MyRotatingLogger:This is log message number 5249
# INFO:MyRotatingLogger:This is log message number 5250
# INFO:MyRotatingLogger:This is log message number 5251
# INFO:MyRotatingLogger:This is log message number 5252
# INFO:MyRotatingLogger:This is log message number 5253
# INFO:MyRotatingLogger:This is log message number 5254
# INFO:MyRotatingLogger:This is log message number 5255
# INFO:MyRotatingLogger:This is log message number 5256
# INFO:MyRotatingLogger:This is log message number 5257
# INFO:MyRotatingLogger:This is log message number 5258
# INFO:MyRotatingLogger:This is log message number 5259
# INFO:MyRotatingLogger:This is log message number 5260
# INFO:MyRotatingLogger:This is log message number 5261
# INFO:MyRotatingLogger:This is log message number 5262
# INFO:MyRotatingLogger:This is log message number 5263
# INFO:MyRotatingLogger:This is log message number 5264
# INFO:MyRotatingLogger:This is log message number 5265
# INFO:MyRotatingLogger:This is log message number 5266
# INFO:MyRotatingLogger:This is log message number 5267
# INFO:MyRotatingLogger:This is log message number 5268
# INFO:MyRotatingLogger:This is log message number 5269
# INFO:MyRotatingLogger:This is log message number 5270
# INFO:MyRotatingLogger:This is log message number 5271
# INFO:MyRotatingLogger:This is log message number 5272
# INFO:MyRotatingLogger:This is log message number 5273
# INFO:MyRotatingLogger:This is log message number 5274
# INFO:MyRotatingLogger:This is log message number 5275
# INFO:MyRotatingLogger:This is log message number 5276
# INFO:MyRotatingLogger:This is log message number 5277
# INFO:MyRotatingLogger:This is log message number 5278
# INFO:MyRotatingLogger:This is log message number 5279
# INFO:MyRotatingLogger:This is log message number 5280
# INFO:MyRotatingLogger:This is log message number 5281
# INFO:MyRotatingLogger:This is log message number 5282
# INFO:MyRotatingLogger:This is log message number 5283
# INFO:MyRotatingLogger:This is log message number 5284
# INFO:MyRotatingLogger:This is log message number 5285
# INFO:MyRotatingLogger:This is log message number 5286
# INFO:MyRotatingLogger:This is log message number 5287
# INFO:MyRotatingLogger:This is log message number 5288
# INFO:MyRotatingLogger:This is log message number 5289
# INFO:MyRotatingLogger:This is log message number 5290
# INFO:MyRotatingLogger:This is log message number 5291
# INFO:MyRotatingLogger:This is log message number 5292
# INFO:MyRotatingLogger:This is log message number 5293
# INFO:MyRotatingLogger:This is log message number 5294
# INFO:MyRotatingLogger:This is log message number 5295
# INFO:MyRotatingLogger:This is log message number 5296
# INFO:MyRotatingLogger:This is log message number 5297
# INFO:MyRotatingLogger:This is log message number 5298
# INFO:MyRotatingLogger:This is log message number 5299
# INFO:MyRotatingLogger:This is log message number 5300
# INFO:MyRotatingLogger:This is log message number 5301
# INFO:MyRotatingLogger:This is log message number 5302
# INFO:MyRotatingLogger:This is log message number 5303
# INFO:MyRotatingLogger:This is log message number 5304
# INFO:MyRotatingLogger:This is log message number 5305
# INFO:MyRotatingLogger:This is log message number 5306
# INFO:MyRotatingLogger:This is log message number 5307
# INFO:MyRotatingLogger:This is log message number 5308
# INFO:MyRotatingLogger:This is log message number 5309
# INFO:MyRotatingLogger:This is log message number 5310
# INFO:MyRotatingLogger:This is log message number 5311
# INFO:MyRotatingLogger:This is log message number 5312
# INFO:MyRotatingLogger:This is log message number 5313
# INFO:MyRotatingLogger:This is log message number 5314
# INFO:MyRotatingLogger:This is log message number 5315
# INFO:MyRotatingLogger:This is log message number 5316
# INFO:MyRotatingLogger:This is log message number 5317
# INFO:MyRotatingLogger:This is log message number 5318
# INFO:MyRotatingLogger:This is log message number 5319
# INFO:MyRotatingLogger:This is log message number 5320
# INFO:MyRotatingLogger:This is log message number 5321
# INFO:MyRotatingLogger:This is log message number 5322
# INFO:MyRotatingLogger:This is log message number 5323
# INFO:MyRotatingLogger:This is log message number 5324
# INFO:MyRotatingLogger:This is log message number 5325
# INFO:MyRotatingLogger:This is log message number 5326
# INFO:MyRotatingLogger:This is log message number 5327
# INFO:MyRotatingLogger:This is log message number 5328
# INFO:MyRotatingLogger:This is log message number 5329
# INFO:MyRotatingLogger:This is log message number 5330
# INFO:MyRotatingLogger:This is log message number 5331
# INFO:MyRotatingLogger:This is log message number 5332
# INFO:MyRotatingLogger:This is log message number 5333
# INFO:MyRotatingLogger:This is log message number 5334
# INFO:MyRotatingLogger:This is log message number 5335
# INFO:MyRotatingLogger:This is log message number 5336
# INFO:MyRotatingLogger:This is log message number 5337
# INFO:MyRotatingLogger:This is log message number 5338
# INFO:MyRotatingLogger:This is log message number 5339
# INFO:MyRotatingLogger:This is log message number 5340
# INFO:MyRotatingLogger:This is log message number 5341
# INFO:MyRotatingLogger:This is log message number 5342
# INFO:MyRotatingLogger:This is log message number 5343
# INFO:MyRotatingLogger:This is log message number 5344
# INFO:MyRotatingLogger:This is log message number 5345
# INFO:MyRotatingLogger:This is log message number 5346
# INFO:MyRotatingLogger:This is log message number 5347
# INFO:MyRotatingLogger:This is log message number 5348
# INFO:MyRotatingLogger:This is log message number 5349
# INFO:MyRotatingLogger:This is log message number 5350
# INFO:MyRotatingLogger:This is log message number 5351
# INFO:MyRotatingLogger:This is log message number 5352
# INFO:MyRotatingLogger:This is log message number 5353
# INFO:MyRotatingLogger:This is log message number 5354
# INFO:MyRotatingLogger:This is log message number 5355
# INFO:MyRotatingLogger:This is log message number 5356
# INFO:MyRotatingLogger:This is log message number 5357
# INFO:MyRotatingLogger:This is log message number 5358
# INFO:MyRotatingLogger:This is log message number 5359
# INFO:MyRotatingLogger:This is log message number 5360
# INFO:MyRotatingLogger:This is log message number 5361
# INFO:MyRotatingLogger:This is log message number 5362
# INFO:MyRotatingLogger:This is log message number 5363
# INFO:MyRotatingLogger:This is log message number 5364
# INFO:MyRotatingLogger:This is log message number 5365
# INFO:MyRotatingLogger:This is log message number 5366
# INFO:MyRotatingLogger:This is log message number 5367
# INFO:MyRotatingLogger:This is log message number 5368
# INFO:MyRotatingLogger:This is log message number 5369
# INFO:MyRotatingLogger:This is log message number 5370
# INFO:MyRotatingLogger:This is log message number 5371
# INFO:MyRotatingLogger:This is log message number 5372
# INFO:MyRotatingLogger:This is log message number 5373
# INFO:MyRotatingLogger:This is log message number 5374
# INFO:MyRotatingLogger:This is log message number 5375
# INFO:MyRotatingLogger:This is log message number 5376
# INFO:MyRotatingLogger:This is log message number 5377
# INFO:MyRotatingLogger:This is log message number 5378
# INFO:MyRotatingLogger:This is log message number 5379
# INFO:MyRotatingLogger:This is log message number 5380
# INFO:MyRotatingLogger:This is log message number 5381
# INFO:MyRotatingLogger:This is log message number 5382
# INFO:MyRotatingLogger:This is log message number 5383
# INFO:MyRotatingLogger:This is log message number 5384
# INFO:MyRotatingLogger:This is log message number 5385
# INFO:MyRotatingLogger:This is log message number 5386
# INFO:MyRotatingLogger:This is log message number 5387
# INFO:MyRotatingLogger:This is log message number 5388
# INFO:MyRotatingLogger:This is log message number 5389
# INFO:MyRotatingLogger:This is log message number 5390
# INFO:MyRotatingLogger:This is log message number 5391
# INFO:MyRotatingLogger:This is log message number 5392
# INFO:MyRotatingLogger:This is log message number 5393
# INFO:MyRotatingLogger:This is log message number 5394
# INFO:MyRotatingLogger:This is log message number 5395
# INFO:MyRotatingLogger:This is log message number 5396
# INFO:MyRotatingLogger:This is log message number 5397
# INFO:MyRotatingLogger:This is log message number 5398
# INFO:MyRotatingLogger:This is log message number 5399
# INFO:MyRotatingLogger:This is log message number 5400
# INFO:MyRotatingLogger:This is log message number 5401
# INFO:MyRotatingLogger:This is log message number 5402
# INFO:MyRotatingLogger:This is log message number 5403
# INFO:MyRotatingLogger:This is log message number 5404
# INFO:MyRotatingLogger:This is log message number 5405
# INFO:MyRotatingLogger:This is log message number 5406
# INFO:MyRotatingLogger:This is log message number 5407
# INFO:MyRotatingLogger:This is log message number 5408
# INFO:MyRotatingLogger:This is log message number 5409
# INFO:MyRotatingLogger:This is log message number 5410
# INFO:MyRotatingLogger:This is log message number 5411
# INFO:MyRotatingLogger:This is log message number 5412
# INFO:MyRotatingLogger:This is log message number 5413
# INFO:MyRotatingLogger:This is log message number 5414
# INFO:MyRotatingLogger:This is log message number 5415
# INFO:MyRotatingLogger:This is log message number 5416
# INFO:MyRotatingLogger:This is log message number 5417
# INFO:MyRotatingLogger:This is log message number 5418
# INFO:MyRotatingLogger:This is log message number 5419
# INFO:MyRotatingLogger:This is log message number 5420
# INFO:MyRotatingLogger:This is log message number 5421
# INFO:MyRotatingLogger:This is log message number 5422
# INFO:MyRotatingLogger:This is log message number 5423
# INFO:MyRotatingLogger:This is log message number 5424
# INFO:MyRotatingLogger:This is log message number 5425
# INFO:MyRotatingLogger:This is log message number 5426
# INFO:MyRotatingLogger:This is log message number 5427
# INFO:MyRotatingLogger:This is log message number 5428
# INFO:MyRotatingLogger:This is log message number 5429
# INFO:MyRotatingLogger:This is log message number 5430
# INFO:MyRotatingLogger:This is log message number 5431
# INFO:MyRotatingLogger:This is log message number 5432
# INFO:MyRotatingLogger:This is log message number 5433
# INFO:MyRotatingLogger:This is log message number 5434
# INFO:MyRotatingLogger:This is log message number 5435
# INFO:MyRotatingLogger:This is log message number 5436
# INFO:MyRotatingLogger:This is log message number 5437
# INFO:MyRotatingLogger:This is log message number 5438
# INFO:MyRotatingLogger:This is log message number 5439
# INFO:MyRotatingLogger:This is log message number 5440
# INFO:MyRotatingLogger:This is log message number 5441
# INFO:MyRotatingLogger:This is log message number 5442
# INFO:MyRotatingLogger:This is log message number 5443
# INFO:MyRotatingLogger:This is log message number 5444
# INFO:MyRotatingLogger:This is log message number 5445
# INFO:MyRotatingLogger:This is log message number 5446
# INFO:MyRotatingLogger:This is log message number 5447
# INFO:MyRotatingLogger:This is log message number 5448
# INFO:MyRotatingLogger:This is log message number 5449
# INFO:MyRotatingLogger:This is log message number 5450
# INFO:MyRotatingLogger:This is log message number 5451
# INFO:MyRotatingLogger:This is log message number 5452
# INFO:MyRotatingLogger:This is log message number 5453
# INFO:MyRotatingLogger:This is log message number 5454
# INFO:MyRotatingLogger:This is log message number 5455
# INFO:MyRotatingLogger:This is log message number 5456
# INFO:MyRotatingLogger:This is log message number 5457
# INFO:MyRotatingLogger:This is log message number 5458
# INFO:MyRotatingLogger:This is log message number 5459
# INFO:MyRotatingLogger:This is log message number 5460
# INFO:MyRotatingLogger:This is log message number 5461
# INFO:MyRotatingLogger:This is log message number 5462
# INFO:MyRotatingLogger:This is log message number 5463
# INFO:MyRotatingLogger:This is log message number 5464
# INFO:MyRotatingLogger:This is log message number 5465
# INFO:MyRotatingLogger:This is log message number 5466
# INFO:MyRotatingLogger:This is log message number 5467
# INFO:MyRotatingLogger:This is log message number 5468
# INFO:MyRotatingLogger:This is log message number 5469
# INFO:MyRotatingLogger:This is log message number 5470
# INFO:MyRotatingLogger:This is log message number 5471
# INFO:MyRotatingLogger:This is log message number 5472
# INFO:MyRotatingLogger:This is log message number 5473
# INFO:MyRotatingLogger:This is log message number 5474
# INFO:MyRotatingLogger:This is log message number 5475
# INFO:MyRotatingLogger:This is log message number 5476
# INFO:MyRotatingLogger:This is log message number 5477
# INFO:MyRotatingLogger:This is log message number 5478
# INFO:MyRotatingLogger:This is log message number 5479
# INFO:MyRotatingLogger:This is log message number 5480
# INFO:MyRotatingLogger:This is log message number 5481
# INFO:MyRotatingLogger:This is log message number 5482
# INFO:MyRotatingLogger:This is log message number 5483
# INFO:MyRotatingLogger:This is log message number 5484
# INFO:MyRotatingLogger:This is log message number 5485
# INFO:MyRotatingLogger:This is log message number 5486
# INFO:MyRotatingLogger:This is log message number 5487
# INFO:MyRotatingLogger:This is log message number 5488
# INFO:MyRotatingLogger:This is log message number 5489
# INFO:MyRotatingLogger:This is log message number 5490
# INFO:MyRotatingLogger:This is log message number 5491
# INFO:MyRotatingLogger:This is log message number 5492
# INFO:MyRotatingLogger:This is log message number 5493
# INFO:MyRotatingLogger:This is log message number 5494
# INFO:MyRotatingLogger:This is log message number 5495
# INFO:MyRotatingLogger:This is log message number 5496
# INFO:MyRotatingLogger:This is log message number 5497
# INFO:MyRotatingLogger:This is log message number 5498
# INFO:MyRotatingLogger:This is log message number 5499
# INFO:MyRotatingLogger:This is log message number 5500
# INFO:MyRotatingLogger:This is log message number 5501
# INFO:MyRotatingLogger:This is log message number 5502
# INFO:MyRotatingLogger:This is log message number 5503
# INFO:MyRotatingLogger:This is log message number 5504
# INFO:MyRotatingLogger:This is log message number 5505
# INFO:MyRotatingLogger:This is log message number 5506
# INFO:MyRotatingLogger:This is log message number 5507
# INFO:MyRotatingLogger:This is log message number 5508
# INFO:MyRotatingLogger:This is log message number 5509
# INFO:MyRotatingLogger:This is log message number 5510
# INFO:MyRotatingLogger:This is log message number 5511
# INFO:MyRotatingLogger:This is log message number 5512
# INFO:MyRotatingLogger:This is log message number 5513
# INFO:MyRotatingLogger:This is log message number 5514
# INFO:MyRotatingLogger:This is log message number 5515
# INFO:MyRotatingLogger:This is log message number 5516
# INFO:MyRotatingLogger:This is log message number 5517
# INFO:MyRotatingLogger:This is log message number 5518
# INFO:MyRotatingLogger:This is log message number 5519
# INFO:MyRotatingLogger:This is log message number 5520
# INFO:MyRotatingLogger:This is log message number 5521
# INFO:MyRotatingLogger:This is log message number 5522
# INFO:MyRotatingLogger:This is log message number 5523
# INFO:MyRotatingLogger:This is log message number 5524
# INFO:MyRotatingLogger:This is log message number 5525
# INFO:MyRotatingLogger:This is log message number 5526
# INFO:MyRotatingLogger:This is log message number 5527
# INFO:MyRotatingLogger:This is log message number 5528
# INFO:MyRotatingLogger:This is log message number 5529
# INFO:MyRotatingLogger:This is log message number 5530
# INFO:MyRotatingLogger:This is log message number 5531
# INFO:MyRotatingLogger:This is log message number 5532
# INFO:MyRotatingLogger:This is log message number 5533
# INFO:MyRotatingLogger:This is log message number 5534
# INFO:MyRotatingLogger:This is log message number 5535
# INFO:MyRotatingLogger:This is log message number 5536
# INFO:MyRotatingLogger:This is log message number 5537
# INFO:MyRotatingLogger:This is log message number 5538
# INFO:MyRotatingLogger:This is log message number 5539
# INFO:MyRotatingLogger:This is log message number 5540
# INFO:MyRotatingLogger:This is log message number 5541
# INFO:MyRotatingLogger:This is log message number 5542
# INFO:MyRotatingLogger:This is log message number 5543
# INFO:MyRotatingLogger:This is log message number 5544
# INFO:MyRotatingLogger:This is log message number 5545
# INFO:MyRotatingLogger:This is log message number 5546
# INFO:MyRotatingLogger:This is log message number 5547
# INFO:MyRotatingLogger:This is log message number 5548
# INFO:MyRotatingLogger:This is log message number 5549
# INFO:MyRotatingLogger:This is log message number 5550
# INFO:MyRotatingLogger:This is log message number 5551
# INFO:MyRotatingLogger:This is log message number 5552
# INFO:MyRotatingLogger:This is log message number 5553
# INFO:MyRotatingLogger:This is log message number 5554
# INFO:MyRotatingLogger:This is log message number 5555
# INFO:MyRotatingLogger:This is log message number 5556
# INFO:MyRotatingLogger:This is log message number 5557
# INFO:MyRotatingLogger:This is log message number 5558
# INFO:MyRotatingLogger:This is log message number 5559
# INFO:MyRotatingLogger:This is log message number 5560
# INFO:MyRotatingLogger:This is log message number 5561
# INFO:MyRotatingLogger:This is log message number 5562
# INFO:MyRotatingLogger:This is log message number 5563
# INFO:MyRotatingLogger:This is log message number 5564
# INFO:MyRotatingLogger:This is log message number 5565
# INFO:MyRotatingLogger:This is log message number 5566
# INFO:MyRotatingLogger:This is log message number 5567
# INFO:MyRotatingLogger:This is log message number 5568
# INFO:MyRotatingLogger:This is log message number 5569
# INFO:MyRotatingLogger:This is log message number 5570
# INFO:MyRotatingLogger:This is log message number 5571
# INFO:MyRotatingLogger:This is log message number 5572
# INFO:MyRotatingLogger:This is log message number 5573
# INFO:MyRotatingLogger:This is log message number 5574
# INFO:MyRotatingLogger:This is log message number 5575
# INFO:MyRotatingLogger:This is log message number 5576
# INFO:MyRotatingLogger:This is log message number 5577
# INFO:MyRotatingLogger:This is log message number 5578
# INFO:MyRotatingLogger:This is log message number 5579
# INFO:MyRotatingLogger:This is log message number 5580
# INFO:MyRotatingLogger:This is log message number 5581
# INFO:MyRotatingLogger:This is log message number 5582
# INFO:MyRotatingLogger:This is log message number 5583
# INFO:MyRotatingLogger:This is log message number 5584
# INFO:MyRotatingLogger:This is log message number 5585
# INFO:MyRotatingLogger:This is log message number 5586
# INFO:MyRotatingLogger:This is log message number 5587
# INFO:MyRotatingLogger:This is log message number 5588
# INFO:MyRotatingLogger:This is log message number 5589
# INFO:MyRotatingLogger:This is log message number 5590
# INFO:MyRotatingLogger:This is log message number 5591
# INFO:MyRotatingLogger:This is log message number 5592
# INFO:MyRotatingLogger:This is log message number 5593
# INFO:MyRotatingLogger:This is log message number 5594
# INFO:MyRotatingLogger:This is log message number 5595
# INFO:MyRotatingLogger:This is log message number 5596
# INFO:MyRotatingLogger:This is log message number 5597
# INFO:MyRotatingLogger:This is log message number 5598
# INFO:MyRotatingLogger:This is log message number 5599
# INFO:MyRotatingLogger:This is log message number 5600
# INFO:MyRotatingLogger:This is log message number 5601
# INFO:MyRotatingLogger:This is log message number 5602
# INFO:MyRotatingLogger:This is log message number 5603
# INFO:MyRotatingLogger:This is log message number 5604
# INFO:MyRotatingLogger:This is log message number 5605
# INFO:MyRotatingLogger:This is log message number 5606
# INFO:MyRotatingLogger:This is log message number 5607
# INFO:MyRotatingLogger:This is log message number 5608
# INFO:MyRotatingLogger:This is log message number 5609
# INFO:MyRotatingLogger:This is log message number 5610
# INFO:MyRotatingLogger:This is log message number 5611
# INFO:MyRotatingLogger:This is log message number 5612
# INFO:MyRotatingLogger:This is log message number 5613
# INFO:MyRotatingLogger:This is log message number 5614
# INFO:MyRotatingLogger:This is log message number 5615
# INFO:MyRotatingLogger:This is log message number 5616
# INFO:MyRotatingLogger:This is log message number 5617
# INFO:MyRotatingLogger:This is log message number 5618
# INFO:MyRotatingLogger:This is log message number 5619
# INFO:MyRotatingLogger:This is log message number 5620
# INFO:MyRotatingLogger:This is log message number 5621
# INFO:MyRotatingLogger:This is log message number 5622
# INFO:MyRotatingLogger:This is log message number 5623
# INFO:MyRotatingLogger:This is log message number 5624
# INFO:MyRotatingLogger:This is log message number 5625
# INFO:MyRotatingLogger:This is log message number 5626
# INFO:MyRotatingLogger:This is log message number 5627
# INFO:MyRotatingLogger:This is log message number 5628
# INFO:MyRotatingLogger:This is log message number 5629
# INFO:MyRotatingLogger:This is log message number 5630
# INFO:MyRotatingLogger:This is log message number 5631
# INFO:MyRotatingLogger:This is log message number 5632
# INFO:MyRotatingLogger:This is log message number 5633
# INFO:MyRotatingLogger:This is log message number 5634
# INFO:MyRotatingLogger:This is log message number 5635
# INFO:MyRotatingLogger:This is log message number 5636
# INFO:MyRotatingLogger:This is log message number 5637
# INFO:MyRotatingLogger:This is log message number 5638
# INFO:MyRotatingLogger:This is log message number 5639
# INFO:MyRotatingLogger:This is log message number 5640
# INFO:MyRotatingLogger:This is log message number 5641
# INFO:MyRotatingLogger:This is log message number 5642
# INFO:MyRotatingLogger:This is log message number 5643
# INFO:MyRotatingLogger:This is log message number 5644
# INFO:MyRotatingLogger:This is log message number 5645
# INFO:MyRotatingLogger:This is log message number 5646
# INFO:MyRotatingLogger:This is log message number 5647
# INFO:MyRotatingLogger:This is log message number 5648
# INFO:MyRotatingLogger:This is log message number 5649
# INFO:MyRotatingLogger:This is log message number 5650
# INFO:MyRotatingLogger:This is log message number 5651
# INFO:MyRotatingLogger:This is log message number 5652
# INFO:MyRotatingLogger:This is log message number 5653
# INFO:MyRotatingLogger:This is log message number 5654
# INFO:MyRotatingLogger:This is log message number 5655
# INFO:MyRotatingLogger:This is log message number 5656
# INFO:MyRotatingLogger:This is log message number 5657
# INFO:MyRotatingLogger:This is log message number 5658
# INFO:MyRotatingLogger:This is log message number 5659
# INFO:MyRotatingLogger:This is log message number 5660
# INFO:MyRotatingLogger:This is log message number 5661
# INFO:MyRotatingLogger:This is log message number 5662
# INFO:MyRotatingLogger:This is log message number 5663
# INFO:MyRotatingLogger:This is log message number 5664
# INFO:MyRotatingLogger:This is log message number 5665
# INFO:MyRotatingLogger:This is log message number 5666
# INFO:MyRotatingLogger:This is log message number 5667
# INFO:MyRotatingLogger:This is log message number 5668
# INFO:MyRotatingLogger:This is log message number 5669
# INFO:MyRotatingLogger:This is log message number 5670
# INFO:MyRotatingLogger:This is log message number 5671
# INFO:MyRotatingLogger:This is log message number 5672
# INFO:MyRotatingLogger:This is log message number 5673
# INFO:MyRotatingLogger:This is log message number 5674
# INFO:MyRotatingLogger:This is log message number 5675
# INFO:MyRotatingLogger:This is log message number 5676
# INFO:MyRotatingLogger:This is log message number 5677
# INFO:MyRotatingLogger:This is log message number 5678
# INFO:MyRotatingLogger:This is log message number 5679
# INFO:MyRotatingLogger:This is log message number 5680
# INFO:MyRotatingLogger:This is log message number 5681
# INFO:MyRotatingLogger:This is log message number 5682
# INFO:MyRotatingLogger:This is log message number 5683
# INFO:MyRotatingLogger:This is log message number 5684
# INFO:MyRotatingLogger:This is log message number 5685
# INFO:MyRotatingLogger:This is log message number 5686
# INFO:MyRotatingLogger:This is log message number 5687
# INFO:MyRotatingLogger:This is log message number 5688
# INFO:MyRotatingLogger:This is log message number 5689
# INFO:MyRotatingLogger:This is log message number 5690
# INFO:MyRotatingLogger:This is log message number 5691
# INFO:MyRotatingLogger:This is log message number 5692
# INFO:MyRotatingLogger:This is log message number 5693
# INFO:MyRotatingLogger:This is log message number 5694
# INFO:MyRotatingLogger:This is log message number 5695
# INFO:MyRotatingLogger:This is log message number 5696
# INFO:MyRotatingLogger:This is log message number 5697
# INFO:MyRotatingLogger:This is log message number 5698
# INFO:MyRotatingLogger:This is log message number 5699
# INFO:MyRotatingLogger:This is log message number 5700
# INFO:MyRotatingLogger:This is log message number 5701
# INFO:MyRotatingLogger:This is log message number 5702
# INFO:MyRotatingLogger:This is log message number 5703
# INFO:MyRotatingLogger:This is log message number 5704
# INFO:MyRotatingLogger:This is log message number 5705
# INFO:MyRotatingLogger:This is log message number 5706
# INFO:MyRotatingLogger:This is log message number 5707
# INFO:MyRotatingLogger:This is log message number 5708
# INFO:MyRotatingLogger:This is log message number 5709
# INFO:MyRotatingLogger:This is log message number 5710
# INFO:MyRotatingLogger:This is log message number 5711
# INFO:MyRotatingLogger:This is log message number 5712
# INFO:MyRotatingLogger:This is log message number 5713
# INFO:MyRotatingLogger:This is log message number 5714
# INFO:MyRotatingLogger:This is log message number 5715
# INFO:MyRotatingLogger:This is log message number 5716
# INFO:MyRotatingLogger:This is log message number 5717
# INFO:MyRotatingLogger:This is log message number 5718
# INFO:MyRotatingLogger:This is log message number 5719
# INFO:MyRotatingLogger:This is log message number 5720
# INFO:MyRotatingLogger:This is log message number 5721
# INFO:MyRotatingLogger:This is log message number 5722
# INFO:MyRotatingLogger:This is log message number 5723
# INFO:MyRotatingLogger:This is log message number 5724
# INFO:MyRotatingLogger:This is log message number 5725
# INFO:MyRotatingLogger:This is log message number 5726
# INFO:MyRotatingLogger:This is log message number 5727
# INFO:MyRotatingLogger:This is log message number 5728
# INFO:MyRotatingLogger:This is log message number 5729
# INFO:MyRotatingLogger:This is log message number 5730
# INFO:MyRotatingLogger:This is log message number 5731
# INFO:MyRotatingLogger:This is log message number 5732
# INFO:MyRotatingLogger:This is log message number 5733
# INFO:MyRotatingLogger:This is log message number 5734
# INFO:MyRotatingLogger:This is log message number 5735
# INFO:MyRotatingLogger:This is log message number 5736
# INFO:MyRotatingLogger:This is log message number 5737
# INFO:MyRotatingLogger:This is log message number 5738
# INFO:MyRotatingLogger:This is log message number 5739
# INFO:MyRotatingLogger:This is log message number 5740
# INFO:MyRotatingLogger:This is log message number 5741
# INFO:MyRotatingLogger:This is log message number 5742
# INFO:MyRotatingLogger:This is log message number 5743
# INFO:MyRotatingLogger:This is log message number 5744
# INFO:MyRotatingLogger:This is log message number 5745
# INFO:MyRotatingLogger:This is log message number 5746
# INFO:MyRotatingLogger:This is log message number 5747
# INFO:MyRotatingLogger:This is log message number 5748
# INFO:MyRotatingLogger:This is log message number 5749
# INFO:MyRotatingLogger:This is log message number 5750
# INFO:MyRotatingLogger:This is log message number 5751
# INFO:MyRotatingLogger:This is log message number 5752
# INFO:MyRotatingLogger:This is log message number 5753
# INFO:MyRotatingLogger:This is log message number 5754
# INFO:MyRotatingLogger:This is log message number 5755
# INFO:MyRotatingLogger:This is log message number 5756
# INFO:MyRotatingLogger:This is log message number 5757
# INFO:MyRotatingLogger:This is log message number 5758
# INFO:MyRotatingLogger:This is log message number 5759
# INFO:MyRotatingLogger:This is log message number 5760
# INFO:MyRotatingLogger:This is log message number 5761
# INFO:MyRotatingLogger:This is log message number 5762
# INFO:MyRotatingLogger:This is log message number 5763
# INFO:MyRotatingLogger:This is log message number 5764
# INFO:MyRotatingLogger:This is log message number 5765
# INFO:MyRotatingLogger:This is log message number 5766
# INFO:MyRotatingLogger:This is log message number 5767
# INFO:MyRotatingLogger:This is log message number 5768
# INFO:MyRotatingLogger:This is log message number 5769
# INFO:MyRotatingLogger:This is log message number 5770
# INFO:MyRotatingLogger:This is log message number 5771
# INFO:MyRotatingLogger:This is log message number 5772
# INFO:MyRotatingLogger:This is log message number 5773
# INFO:MyRotatingLogger:This is log message number 5774
# INFO:MyRotatingLogger:This is log message number 5775
# INFO:MyRotatingLogger:This is log message number 5776
# INFO:MyRotatingLogger:This is log message number 5777
# INFO:MyRotatingLogger:This is log message number 5778
# INFO:MyRotatingLogger:This is log message number 5779
# INFO:MyRotatingLogger:This is log message number 5780
# INFO:MyRotatingLogger:This is log message number 5781
# INFO:MyRotatingLogger:This is log message number 5782
# INFO:MyRotatingLogger:This is log message number 5783
# INFO:MyRotatingLogger:This is log message number 5784
# INFO:MyRotatingLogger:This is log message number 5785
# INFO:MyRotatingLogger:This is log message number 5786
# INFO:MyRotatingLogger:This is log message number 5787
# INFO:MyRotatingLogger:This is log message number 5788
# INFO:MyRotatingLogger:This is log message number 5789
# INFO:MyRotatingLogger:This is log message number 5790
# INFO:MyRotatingLogger:This is log message number 5791
# INFO:MyRotatingLogger:This is log message number 5792
# INFO:MyRotatingLogger:This is log message number 5793
# INFO:MyRotatingLogger:This is log message number 5794
# INFO:MyRotatingLogger:This is log message number 5795
# INFO:MyRotatingLogger:This is log message number 5796
# INFO:MyRotatingLogger:This is log message number 5797
# INFO:MyRotatingLogger:This is log message number 5798
# INFO:MyRotatingLogger:This is log message number 5799
# INFO:MyRotatingLogger:This is log message number 5800
# INFO:MyRotatingLogger:This is log message number 5801
# INFO:MyRotatingLogger:This is log message number 5802
# INFO:MyRotatingLogger:This is log message number 5803
# INFO:MyRotatingLogger:This is log message number 5804
# INFO:MyRotatingLogger:This is log message number 5805
# INFO:MyRotatingLogger:This is log message number 5806
# INFO:MyRotatingLogger:This is log message number 5807
# INFO:MyRotatingLogger:This is log message number 5808
# INFO:MyRotatingLogger:This is log message number 5809
# INFO:MyRotatingLogger:This is log message number 5810
# INFO:MyRotatingLogger:This is log message number 5811
# INFO:MyRotatingLogger:This is log message number 5812
# INFO:MyRotatingLogger:This is log message number 5813
# INFO:MyRotatingLogger:This is log message number 5814
# INFO:MyRotatingLogger:This is log message number 5815
# INFO:MyRotatingLogger:This is log message number 5816
# INFO:MyRotatingLogger:This is log message number 5817
# INFO:MyRotatingLogger:This is log message number 5818
# INFO:MyRotatingLogger:This is log message number 5819
# INFO:MyRotatingLogger:This is log message number 5820
# INFO:MyRotatingLogger:This is log message number 5821
# INFO:MyRotatingLogger:This is log message number 5822
# INFO:MyRotatingLogger:This is log message number 5823
# INFO:MyRotatingLogger:This is log message number 5824
# INFO:MyRotatingLogger:This is log message number 5825
# INFO:MyRotatingLogger:This is log message number 5826
# INFO:MyRotatingLogger:This is log message number 5827
# INFO:MyRotatingLogger:This is log message number 5828
# INFO:MyRotatingLogger:This is log message number 5829
# INFO:MyRotatingLogger:This is log message number 5830
# INFO:MyRotatingLogger:This is log message number 5831
# INFO:MyRotatingLogger:This is log message number 5832
# INFO:MyRotatingLogger:This is log message number 5833
# INFO:MyRotatingLogger:This is log message number 5834
# INFO:MyRotatingLogger:This is log message number 5835
# INFO:MyRotatingLogger:This is log message number 5836
# INFO:MyRotatingLogger:This is log message number 5837
# INFO:MyRotatingLogger:This is log message number 5838
# INFO:MyRotatingLogger:This is log message number 5839
# INFO:MyRotatingLogger:This is log message number 5840
# INFO:MyRotatingLogger:This is log message number 5841
# INFO:MyRotatingLogger:This is log message number 5842
# INFO:MyRotatingLogger:This is log message number 5843
# INFO:MyRotatingLogger:This is log message number 5844
# INFO:MyRotatingLogger:This is log message number 5845
# INFO:MyRotatingLogger:This is log message number 5846
# INFO:MyRotatingLogger:This is log message number 5847
# INFO:MyRotatingLogger:This is log message number 5848
# INFO:MyRotatingLogger:This is log message number 5849
# INFO:MyRotatingLogger:This is log message number 5850
# INFO:MyRotatingLogger:This is log message number 5851
# INFO:MyRotatingLogger:This is log message number 5852
# INFO:MyRotatingLogger:This is log message number 5853
# INFO:MyRotatingLogger:This is log message number 5854
# INFO:MyRotatingLogger:This is log message number 5855
# INFO:MyRotatingLogger:This is log message number 5856
# INFO:MyRotatingLogger:This is log message number 5857
# INFO:MyRotatingLogger:This is log message number 5858
# INFO:MyRotatingLogger:This is log message number 5859
# INFO:MyRotatingLogger:This is log message number 5860
# INFO:MyRotatingLogger:This is log message number 5861
# INFO:MyRotatingLogger:This is log message number 5862
# INFO:MyRotatingLogger:This is log message number 5863
# INFO:MyRotatingLogger:This is log message number 5864
# INFO:MyRotatingLogger:This is log message number 5865
# INFO:MyRotatingLogger:This is log message number 5866
# INFO:MyRotatingLogger:This is log message number 5867
# INFO:MyRotatingLogger:This is log message number 5868
# INFO:MyRotatingLogger:This is log message number 5869
# INFO:MyRotatingLogger:This is log message number 5870
# INFO:MyRotatingLogger:This is log message number 5871
# INFO:MyRotatingLogger:This is log message number 5872
# INFO:MyRotatingLogger:This is log message number 5873
# INFO:MyRotatingLogger:This is log message number 5874
# INFO:MyRotatingLogger:This is log message number 5875
# INFO:MyRotatingLogger:This is log message number 5876
# INFO:MyRotatingLogger:This is log message number 5877
# INFO:MyRotatingLogger:This is log message number 5878
# INFO:MyRotatingLogger:This is log message number 5879
# INFO:MyRotatingLogger:This is log message number 5880
# INFO:MyRotatingLogger:This is log message number 5881
# INFO:MyRotatingLogger:This is log message number 5882
# INFO:MyRotatingLogger:This is log message number 5883
# INFO:MyRotatingLogger:This is log message number 5884
# INFO:MyRotatingLogger:This is log message number 5885
# INFO:MyRotatingLogger:This is log message number 5886
# ...
# INFO:MyRotatingLogger:This is log message number 9704
# INFO:MyRotatingLogger:This is log message number 9705
# INFO:MyRotatingLogger:This is log message number 9706
# INFO:MyRotatingLogger:This is log message number 9707
# INFO:MyRotatingLogger:This is log message number 9708
# INFO:MyRotatingLogger:This is log message number 9709
# INFO:MyRotatingLogger:This is log message number 9710
# INFO:MyRotatingLogger:This is log message number 9711
# INFO:MyRotatingLogger:This is log message number 9712
# INFO:MyRotatingLogger:This is log message number 9713
# INFO:MyRotatingLogger:This is log message number 9714
# INFO:MyRotatingLogger:This is log message number 9715
# INFO:MyRotatingLogger:This is log message number 9716
# INFO:MyRotatingLogger:This is log message number 9717
# INFO:MyRotatingLogger:This is log message number 9718
# INFO:MyRotatingLogger:This is log message number 9719
# INFO:MyRotatingLogger:This is log message number 9720
# INFO:MyRotatingLogger:This is log message number 9721
# INFO:MyRotatingLogger:This is log message number 9722
# INFO:MyRotatingLogger:This is log message number 9723
# INFO:MyRotatingLogger:This is log message number 9724
# INFO:MyRotatingLogger:This is log message number 9725
# INFO:MyRotatingLogger:This is log message number 9726
# INFO:MyRotatingLogger:This is log message number 9727
# INFO:MyRotatingLogger:This is log message number 9728
# INFO:MyRotatingLogger:This is log message number 9729
# INFO:MyRotatingLogger:This is log message number 9730
# INFO:MyRotatingLogger:This is log message number 9731
# INFO:MyRotatingLogger:This is log message number 9732
# INFO:MyRotatingLogger:This is log message number 9733
# INFO:MyRotatingLogger:This is log message number 9734
# INFO:MyRotatingLogger:This is log message number 9735
# INFO:MyRotatingLogger:This is log message number 9736
# INFO:MyRotatingLogger:This is log message number 9737
# INFO:MyRotatingLogger:This is log message number 9738
# INFO:MyRotatingLogger:This is log message number 9739
# INFO:MyRotatingLogger:This is log message number 9740
# INFO:MyRotatingLogger:This is log message number 9741
# INFO:MyRotatingLogger:This is log message number 9742
# INFO:MyRotatingLogger:This is log message number 9743
# INFO:MyRotatingLogger:This is log message number 9744
# INFO:MyRotatingLogger:This is log message number 9745
# INFO:MyRotatingLogger:This is log message number 9746
# INFO:MyRotatingLogger:This is log message number 9747
# INFO:MyRotatingLogger:This is log message number 9748
# INFO:MyRotatingLogger:This is log message number 9749
# INFO:MyRotatingLogger:This is log message number 9750
# INFO:MyRotatingLogger:This is log message number 9751
# INFO:MyRotatingLogger:This is log message number 9752
# INFO:MyRotatingLogger:This is log message number 9753
# INFO:MyRotatingLogger:This is log message number 9754
# INFO:MyRotatingLogger:This is log message number 9755
# INFO:MyRotatingLogger:This is log message number 9756
# INFO:MyRotatingLogger:This is log message number 9757
# INFO:MyRotatingLogger:This is log message number 9758
# INFO:MyRotatingLogger:This is log message number 9759
# INFO:MyRotatingLogger:This is log message number 9760
# INFO:MyRotatingLogger:This is log message number 9761
# INFO:MyRotatingLogger:This is log message number 9762
# INFO:MyRotatingLogger:This is log message number 9763
# INFO:MyRotatingLogger:This is log message number 9764
# INFO:MyRotatingLogger:This is log message number 9765
# INFO:MyRotatingLogger:This is log message number 9766
# INFO:MyRotatingLogger:This is log message number 9767
# INFO:MyRotatingLogger:This is log message number 9768
# INFO:MyRotatingLogger:This is log message number 9769
# INFO:MyRotatingLogger:This is log message number 9770
# INFO:MyRotatingLogger:This is log message number 9771
# INFO:MyRotatingLogger:This is log message number 9772
# INFO:MyRotatingLogger:This is log message number 9773
# INFO:MyRotatingLogger:This is log message number 9774
# INFO:MyRotatingLogger:This is log message number 9775
# INFO:MyRotatingLogger:This is log message number 9776
# INFO:MyRotatingLogger:This is log message number 9777
# INFO:MyRotatingLogger:This is log message number 9778
# INFO:MyRotatingLogger:This is log message number 9779
# INFO:MyRotatingLogger:This is log message number 9780
# INFO:MyRotatingLogger:This is log message number 9781
# INFO:MyRotatingLogger:This is log message number 9782
# INFO:MyRotatingLogger:This is log message number 9783
# INFO:MyRotatingLogger:This is log message number 9784
# INFO:MyRotatingLogger:This is log message number 9785
# INFO:MyRotatingLogger:This is log message number 9786
# INFO:MyRotatingLogger:This is log message number 9787
# INFO:MyRotatingLogger:This is log message number 9788
# INFO:MyRotatingLogger:This is log message number 9789
# INFO:MyRotatingLogger:This is log message number 9790
# INFO:MyRotatingLogger:This is log message number 9791
# INFO:MyRotatingLogger:This is log message number 9792
# INFO:MyRotatingLogger:This is log message number 9793
# INFO:MyRotatingLogger:This is log message number 9794
# INFO:MyRotatingLogger:This is log message number 9795
# INFO:MyRotatingLogger:This is log message number 9796
# INFO:MyRotatingLogger:This is log message number 9797
# INFO:MyRotatingLogger:This is log message number 9798
# INFO:MyRotatingLogger:This is log message number 9799
# INFO:MyRotatingLogger:This is log message number 9800
# INFO:MyRotatingLogger:This is log message number 9801
# INFO:MyRotatingLogger:This is log message number 9802
# INFO:MyRotatingLogger:This is log message number 9803
# INFO:MyRotatingLogger:This is log message number 9804
# INFO:MyRotatingLogger:This is log message number 9805
# INFO:MyRotatingLogger:This is log message number 9806
# INFO:MyRotatingLogger:This is log message number 9807
# INFO:MyRotatingLogger:This is log message number 9808
# INFO:MyRotatingLogger:This is log message number 9809
# INFO:MyRotatingLogger:This is log message number 9810
# INFO:MyRotatingLogger:This is log message number 9811
# INFO:MyRotatingLogger:This is log message number 9812
# INFO:MyRotatingLogger:This is log message number 9813
# INFO:MyRotatingLogger:This is log message number 9814
# INFO:MyRotatingLogger:This is log message number 9815
# INFO:MyRotatingLogger:This is log message number 9816
# INFO:MyRotatingLogger:This is log message number 9817
# INFO:MyRotatingLogger:This is log message number 9818
# INFO:MyRotatingLogger:This is log message number 9819
# INFO:MyRotatingLogger:This is log message number 9820
# INFO:MyRotatingLogger:This is log message number 9821
# INFO:MyRotatingLogger:This is log message number 9822
# INFO:MyRotatingLogger:This is log message number 9823
# INFO:MyRotatingLogger:This is log message number 9824
# INFO:MyRotatingLogger:This is log message number 9825
# INFO:MyRotatingLogger:This is log message number 9826
# INFO:MyRotatingLogger:This is log message number 9827
# INFO:MyRotatingLogger:This is log message number 9828
# INFO:MyRotatingLogger:This is log message number 9829
# INFO:MyRotatingLogger:This is log message number 9830
# INFO:MyRotatingLogger:This is log message number 9831
# INFO:MyRotatingLogger:This is log message number 9832
# INFO:MyRotatingLogger:This is log message number 9833
# INFO:MyRotatingLogger:This is log message number 9834
# INFO:MyRotatingLogger:This is log message number 9835
# INFO:MyRotatingLogger:This is log message number 9836
# INFO:MyRotatingLogger:This is log message number 9837
# INFO:MyRotatingLogger:This is log message number 9838
# INFO:MyRotatingLogger:This is log message number 9839
# INFO:MyRotatingLogger:This is log message number 9840
# INFO:MyRotatingLogger:This is log message number 9841
# INFO:MyRotatingLogger:This is log message number 9842
# INFO:MyRotatingLogger:This is log message number 9843
# INFO:MyRotatingLogger:This is log message number 9844
# INFO:MyRotatingLogger:This is log message number 9845
# INFO:MyRotatingLogger:This is log message number 9846
# INFO:MyRotatingLogger:This is log message number 9847
# INFO:MyRotatingLogger:This is log message number 9848
# INFO:MyRotatingLogger:This is log message number 9849
# INFO:MyRotatingLogger:This is log message number 9850
# INFO:MyRotatingLogger:This is log message number 9851
# INFO:MyRotatingLogger:This is log message number 9852
# INFO:MyRotatingLogger:This is log message number 9853
# INFO:MyRotatingLogger:This is log message number 9854
# INFO:MyRotatingLogger:This is log message number 9855
# INFO:MyRotatingLogger:This is log message number 9856
# INFO:MyRotatingLogger:This is log message number 9857
# INFO:MyRotatingLogger:This is log message number 9858
# INFO:MyRotatingLogger:This is log message number 9859
# INFO:MyRotatingLogger:This is log message number 9860
# INFO:MyRotatingLogger:This is log message number 9861
# INFO:MyRotatingLogger:This is log message number 9862
# INFO:MyRotatingLogger:This is log message number 9863
# INFO:MyRotatingLogger:This is log message number 9864
# INFO:MyRotatingLogger:This is log message number 9865
# INFO:MyRotatingLogger:This is log message number 9866
# INFO:MyRotatingLogger:This is log message number 9867
# INFO:MyRotatingLogger:This is log message number 9868
# INFO:MyRotatingLogger:This is log message number 9869
# INFO:MyRotatingLogger:This is log message number 9870
# INFO:MyRotatingLogger:This is log message number 9871
# INFO:MyRotatingLogger:This is log message number 9872
# INFO:MyRotatingLogger:This is log message number 9873
# INFO:MyRotatingLogger:This is log message number 9874
# INFO:MyRotatingLogger:This is log message number 9875
# INFO:MyRotatingLogger:This is log message number 9876
# INFO:MyRotatingLogger:This is log message number 9877
# INFO:MyRotatingLogger:This is log message number 9878
# INFO:MyRotatingLogger:This is log message number 9879
# INFO:MyRotatingLogger:This is log message number 9880
# INFO:MyRotatingLogger:This is log message number 9881
# INFO:MyRotatingLogger:This is log message number 9882
# INFO:MyRotatingLogger:This is log message number 9883
# INFO:MyRotatingLogger:This is log message number 9884
# INFO:MyRotatingLogger:This is log message number 9885
# INFO:MyRotatingLogger:This is log message number 9886
# INFO:MyRotatingLogger:This is log message number 9887
# INFO:MyRotatingLogger:This is log message number 9888
# INFO:MyRotatingLogger:This is log message number 9889
# INFO:MyRotatingLogger:This is log message number 9890
# INFO:MyRotatingLogger:This is log message number 9891
# INFO:MyRotatingLogger:This is log message number 9892
# INFO:MyRotatingLogger:This is log message number 9893
# INFO:MyRotatingLogger:This is log message number 9894
# INFO:MyRotatingLogger:This is log message number 9895
# INFO:MyRotatingLogger:This is log message number 9896
# INFO:MyRotatingLogger:This is log message number 9897
# INFO:MyRotatingLogger:This is log message number 9898
# INFO:MyRotatingLogger:This is log message number 9899
# INFO:MyRotatingLogger:This is log message number 9900
# INFO:MyRotatingLogger:This is log message number 9901
# INFO:MyRotatingLogger:This is log message number 9902
# INFO:MyRotatingLogger:This is log message number 9903
# INFO:MyRotatingLogger:This is log message number 9904
# INFO:MyRotatingLogger:This is log message number 9905
# INFO:MyRotatingLogger:This is log message number 9906
# INFO:MyRotatingLogger:This is log message number 9907
# INFO:MyRotatingLogger:This is log message number 9908
# INFO:MyRotatingLogger:This is log message number 9909
# INFO:MyRotatingLogger:This is log message number 9910
# INFO:MyRotatingLogger:This is log message number 9911
# INFO:MyRotatingLogger:This is log message number 9912
# INFO:MyRotatingLogger:This is log message number 9913
# INFO:MyRotatingLogger:This is log message number 9914
# INFO:MyRotatingLogger:This is log message number 9915
# INFO:MyRotatingLogger:This is log message number 9916
# INFO:MyRotatingLogger:This is log message number 9917
# INFO:MyRotatingLogger:This is log message number 9918
# INFO:MyRotatingLogger:This is log message number 9919
# INFO:MyRotatingLogger:This is log message number 9920
# INFO:MyRotatingLogger:This is log message number 9921
# INFO:MyRotatingLogger:This is log message number 9922
# INFO:MyRotatingLogger:This is log message number 9923
# INFO:MyRotatingLogger:This is log message number 9924
# INFO:MyRotatingLogger:This is log message number 9925
# INFO:MyRotatingLogger:This is log message number 9926
# INFO:MyRotatingLogger:This is log message number 9927
# INFO:MyRotatingLogger:This is log message number 9928
# INFO:MyRotatingLogger:This is log message number 9929
# INFO:MyRotatingLogger:This is log message number 9930
# INFO:MyRotatingLogger:This is log message number 9931
# INFO:MyRotatingLogger:This is log message number 9932
# INFO:MyRotatingLogger:This is log message number 9933
# INFO:MyRotatingLogger:This is log message number 9934
# INFO:MyRotatingLogger:This is log message number 9935
# INFO:MyRotatingLogger:This is log message number 9936
# INFO:MyRotatingLogger:This is log message number 9937
# INFO:MyRotatingLogger:This is log message number 9938
# INFO:MyRotatingLogger:This is log message number 9939
# INFO:MyRotatingLogger:This is log message number 9940
# INFO:MyRotatingLogger:This is log message number 9941
# INFO:MyRotatingLogger:This is log message number 9942
# INFO:MyRotatingLogger:This is log message number 9943
# INFO:MyRotatingLogger:This is log message number 9944
# INFO:MyRotatingLogger:This is log message number 9945
# INFO:MyRotatingLogger:This is log message number 9946
# INFO:MyRotatingLogger:This is log message number 9947
# INFO:MyRotatingLogger:This is log message number 9948
# INFO:MyRotatingLogger:This is log message number 9949
# INFO:MyRotatingLogger:This is log message number 9950
# INFO:MyRotatingLogger:This is log message number 9951
# INFO:MyRotatingLogger:This is log message number 9952
# INFO:MyRotatingLogger:This is log message number 9953
# INFO:MyRotatingLogger:This is log message number 9954
# INFO:MyRotatingLogger:This is log message number 9955
# INFO:MyRotatingLogger:This is log message number 9956
# INFO:MyRotatingLogger:This is log message number 9957
# INFO:MyRotatingLogger:This is log message number 9958
# INFO:MyRotatingLogger:This is log message number 9959
# INFO:MyRotatingLogger:This is log message number 9960
# INFO:MyRotatingLogger:This is log message number 9961
# INFO:MyRotatingLogger:This is log message number 9962
# INFO:MyRotatingLogger:This is log message number 9963
# INFO:MyRotatingLogger:This is log message number 9964
# INFO:MyRotatingLogger:This is log message number 9965
# INFO:MyRotatingLogger:This is log message number 9966
# INFO:MyRotatingLogger:This is log message number 9967
# INFO:MyRotatingLogger:This is log message number 9968
# INFO:MyRotatingLogger:This is log message number 9969
# INFO:MyRotatingLogger:This is log message number 9970
# INFO:MyRotatingLogger:This is log message number 9971
# INFO:MyRotatingLogger:This is log message number 9972
# INFO:MyRotatingLogger:This is log message number 9973
# INFO:MyRotatingLogger:This is log message number 9974
# INFO:MyRotatingLogger:This is log message number 9975
# INFO:MyRotatingLogger:This is log message number 9976
# INFO:MyRotatingLogger:This is log message number 9977
# INFO:MyRotatingLogger:This is log message number 9978
# INFO:MyRotatingLogger:This is log message number 9979
# INFO:MyRotatingLogger:This is log message number 9980
# INFO:MyRotatingLogger:This is log message number 9981
# INFO:MyRotatingLogger:This is log message number 9982
# INFO:MyRotatingLogger:This is log message number 9983
# INFO:MyRotatingLogger:This is log message number 9984
# INFO:MyRotatingLogger:This is log message number 9985
# INFO:MyRotatingLogger:This is log message number 9986
# INFO:MyRotatingLogger:This is log message number 9987
# INFO:MyRotatingLogger:This is log message number 9988
# INFO:MyRotatingLogger:This is log message number 9989
# INFO:MyRotatingLogger:This is log message number 9990
# INFO:MyRotatingLogger:This is log message number 9991
# INFO:MyRotatingLogger:This is log message number 9992
# INFO:MyRotatingLogger:This is log message number 9993
# INFO:MyRotatingLogger:This is log message number 9994
# INFO:MyRotatingLogger:This is log message number 9995
# INFO:MyRotatingLogger:This is log message number 9996
# INFO:MyRotatingLogger:This is log message number 9997
# INFO:MyRotatingLogger:This is log message number 9998
# INFO:MyRotatingLogger:This is log message number 9999

# %% [markdown]
# **19. Write a program that handles both IndexError and KeyError using a try-except block.**

# %%
try:
    my_list = [1, 2]
    print(my_list[5])
    my_dict = {"a": 1}
    print(my_dict["b"])
except IndexError:
    print("IndexError caught.")
except KeyError:
    print("KeyError caught.")
# Out:
# IndexError caught.

# %% [markdown]
# **20. How would you open a file and read its contents using a context manager in Python?**

# %%
with open("example1.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# This is a sample text written to the file.
# This is an appended line.

# %% [markdown]
# **21. Write a Python program that reads a file and prints the number of occurrences of a specific word.**

# %%
def count_word_occurrences(filename, target_word):
    try:
        with open(filename, 'r') as file:
            content = file.read().lower()
            words = content.split()
            count = words.count(target_word.lower())
            print(f"The word '{target_word}' appears {count} times in '{filename}'.")
    except FileNotFoundError:
        print(f"The file '{filename}' was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
file_name = input("Enter the file name (e.g., notes.txt): ")
word_to_search = input("Enter the word to count: ")

count_word_occurrences(file_name, word_to_search)
# Out:
# Enter the file name (e.g., notes.txt): example.txt
# Enter the word to count: hello
# The word 'hello' appears 0 times in 'example.txt'.

# %% [markdown]
# **22. How can you check if a file is empty before attempting to read its contents?**

# %%
import os

filename = "sample.txt"

try:
    if os.path.exists(filename) and os.path.getsize(filename) > 0:
        print("File exists and is not empty.")
    else:
        print("File is either missing or empty.")
except Exception as e:
    print("Error while checking file:", e)
# Out:
# File is either missing or empty.

# %% [markdown]
# **23. Write a Python program that writes to a log file when an error occurs during file handling.**

# %%
import logging

# Configure the logger
logging.basicConfig(
    filename='file_errors.log',         # Log file name
    level=logging.ERROR,                # Only log errors or higher
    format='%(asctime)s - %(levelname)s - %(message)s'
)

def read_file(filename):
    try:
        with open(filename, 'r') as file:
            content = file.read()
            print("File contents:\n", content)
    except FileNotFoundError as e:
        logging.error(f"File not found: {filename}")
        print("Error: File not found.")
    except PermissionError as e:
        logging.error(f"Permission denied: {filename}")
        print("Error: You don't have permission to read this file.")
    except Exception as e:
        logging.error(f"Unexpected error with '{filename}': {e}")
        print("An unexpected error occurred.")

# Example usage
filename = input("Enter the file name to read: ")
read_file(filename)
# Out:
# Enter the file name to read: example.txt
# File contents:
#  Hello, World!
